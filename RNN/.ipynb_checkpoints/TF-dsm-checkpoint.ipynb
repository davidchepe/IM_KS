# %% [markdown]
# ### BLOQUE DE IMPORT DE PAQUETES

# %% [markdown]
# #### Añadir los install

# %%
from keras.models import Sequential
from keras.layers import Dense
#from sklearn.datasets.samples_generator import make_blobs

from sklearn.preprocessing import RobustScaler

#from sklearn.model_selection import KFold
#from sklearn.model_selection import cross_val_score

import pickle

import datetime

import numpy as np
import pandas as pd

import matplotlib.pylab as plt
# %matplotlib inline
plt.style.use('seaborn')
# Out:
# C:\Users\eduardo.hernanz\AppData\Local\Continuum\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ### Filtramos datos:
# Pendientes <> inf
#
# Tramos cortos
#
# Velocidades bajas
#
# Como usamos entrenamientos amateurs y las mediciones están hechas con relojes (que tienen cierto grado de imprecisión), filtramos para tener datos más estables y que el modelo generalice mejor

# %%
path = '../Entrenamientos/Procesado_Tramos.xlsx'
df = pd.read_excel(path)
df = df[df["porc"]!=np.inf]
df["puntos_en_tramo"]= df["tramo_final"]-df["tramo_inicial"]
df = df[df["puntos_en_tramo"]>9]
df = df[df["spd"]>5]

#Ya tenemos el dataframe filtrado

# %% [markdown]
# ### Para hacer train-test tradicional
#
# Lo mantenemos en el código porque puede ser usado para validar el modelo de forma generalizada. En primer lugar tomábamos datos de todos los entrenamientos y validábamos también con datos procedentes de cualquier entrenamiento

# %% [markdown]
# df2 = df[["pwr","porc","viento_aparente","spd"]]
# dataset = df2.values
#
# X = dataset[:,0:3]
# Y = dataset[:,3]
#
# X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.30, random_state=42)

# %% [markdown]
# ### Separación de datos en Train y Test
#
# Hemos hecho diferentes pruebas, incluso entrenando la red con 1 sólo entrenamiento y los resultados son satisfactorios. La diferencia entre las velocidades reales y las predichas son del mismo orden que si entrenamos con mayor cantidad de puntos. El histograma de diferencias sigue una distribución normal

# %%
#Para entrenar con una prueba y predecir otra:

entreno = '20180527_LEVS_195_90_C_E.gpx'
prueba = '20180429_LEMG_195_90_R_C.gpx'

df_train = df[df['prueba']==entreno]
df_test = df[df['prueba']==prueba]

# %% [markdown]
# #Para entrenar con varias pruebas y predecir otra:
#
# prueba = '20180429_LEMG_195_90_R_C.gpx'
#
# df_train = df[df['prueba']!=prueba]
# df_test = df[df['prueba']==prueba]

# %% [markdown]
# #### Comprobamos que se ha hecho correctamente el split entre Test y Train

# %%
df_train.prueba.unique()
# Out:
# array(['20180527_LEVS_195_90_C_E.gpx'], dtype=object)

# %%
df_test.prueba.unique()
# Out:
# array(['20180429_LEMG_195_90_R_C.gpx'], dtype=object)

# %%
X_train = df_train[["pwr","porc","viento_aparente"]] 
X_test = df_test[["pwr","porc","viento_aparente"]]
Y_train = df_train[["spd"]]
Y_test = df_test[["spd"]]

# %% [markdown]
# ### Preprocesado: Escalado para evitar atípicos

# %%
scalarX = RobustScaler()

X_train_rs = scalarX.fit_transform(X_train)
X_test_rs = scalarX.transform(X_test)

# %% [markdown]
# ### Modelado de la Red: Inicialización y Definición

# %%
#Probar por diferentes funciones de activacion y con regularizacion

# define and fit the final model
#model.reset_states()
model = Sequential()

model.add(Dense(4, input_dim=3, activation='relu'))
model.add(Dense(60, activation='relu'))
model.add(Dense(20, activation='relu'))
model.add(Dense(1, activation='linear'))

model.compile(loss='mse', optimizer='adam', metrics=['mse', 'mae', 'mape'])

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 4)                 16
# _________________________________________________________________
# dense_2 (Dense)              (None, 60)                300
# _________________________________________________________________
# dense_3 (Dense)              (None, 20)                1220
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 21
# =================================================================
# Total params: 1,557
# Trainable params: 1,557
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Entrenamiento del Modelo

# %%
history = model.fit(X_train_rs, Y_train, batch_size=10, validation_data=(X_test_rs,Y_test), epochs=400, verbose=2)
# Out:
# Train on 121 samples, validate on 80 samples
# Epoch 1/400
#  - 0s - loss: 1182.5205 - mean_squared_error: 1182.5205 - mean_absolute_error: 33.7573 - mean_absolute_percentage_error: 99.6286 - val_loss: 1234.0128 - val_mean_squared_error: 1234.0128 - val_mean_absolute_error: 33.2187 - val_mean_absolute_percentage_error: 98.6025
# Epoch 2/400
#  - 0s - loss: 1155.6010 - mean_squared_error: 1155.6010 - mean_absolute_error: 33.3631 - mean_absolute_percentage_error: 98.4265 - val_loss: 1196.2772 - val_mean_squared_error: 1196.2772 - val_mean_absolute_error: 32.6807 - val_mean_absolute_percentage_error: 96.8417
# Epoch 3/400
#  - 0s - loss: 1121.4552 - mean_squared_error: 1121.4552 - mean_absolute_error: 32.8601 - mean_absolute_percentage_error: 96.9118 - val_loss: 1145.9456 - val_mean_squared_error: 1145.9456 - val_mean_absolute_error: 31.9468 - val_mean_absolute_percentage_error: 94.4447
# Epoch 4/400
#  - 0s - loss: 1074.0434 - mean_squared_error: 1074.0434 - mean_absolute_error: 32.1473 - mean_absolute_percentage_error: 94.7655 - val_loss: 1081.7775 - val_mean_squared_error: 1081.7775 - val_mean_absolute_error: 30.9761 - val_mean_absolute_percentage_error: 91.2679
# Epoch 5/400
#  - 0s - loss: 1011.3842 - mean_squared_error: 1011.3842 - mean_absolute_error: 31.1686 - mean_absolute_percentage_error: 91.7993 - val_loss: 990.8674 - val_mean_squared_error: 990.8674 - val_mean_absolute_error: 29.5556 - val_mean_absolute_percentage_error: 86.6985
# Epoch 6/400
#  - 0s - loss: 919.9423 - mean_squared_error: 919.9423 - mean_absolute_error: 29.7013 - mean_absolute_percentage_error: 87.4599 - val_loss: 870.3990 - val_mean_squared_error: 870.3990 - val_mean_absolute_error: 27.5529 - val_mean_absolute_percentage_error: 80.3379
# Epoch 7/400
#  - 0s - loss: 805.2367 - mean_squared_error: 805.2367 - mean_absolute_error: 27.7017 - mean_absolute_percentage_error: 81.4727 - val_loss: 722.8387 - val_mean_squared_error: 722.8387 - val_mean_absolute_error: 24.8513 - val_mean_absolute_percentage_error: 71.8990
# Epoch 8/400
#  - 0s - loss: 665.1196 - mean_squared_error: 665.1196 - mean_absolute_error: 25.0372 - mean_absolute_percentage_error: 73.5861 - val_loss: 558.9270 - val_mean_squared_error: 558.9270 - val_mean_absolute_error: 21.4675 - val_mean_absolute_percentage_error: 62.0064
# Epoch 9/400
#  - 0s - loss: 513.9963 - mean_squared_error: 513.9963 - mean_absolute_error: 21.5948 - mean_absolute_percentage_error: 63.3018 - val_loss: 406.6487 - val_mean_squared_error: 406.6487 - val_mean_absolute_error: 17.7374 - val_mean_absolute_percentage_error: 52.2608
# Epoch 10/400
#  - 0s - loss: 368.4690 - mean_squared_error: 368.4690 - mean_absolute_error: 17.7247 - mean_absolute_percentage_error: 51.9256 - val_loss: 292.0098 - val_mean_squared_error: 292.0098 - val_mean_absolute_error: 14.3416 - val_mean_absolute_percentage_error: 43.6491
# Epoch 11/400
#  - 0s - loss: 257.4022 - mean_squared_error: 257.4022 - mean_absolute_error: 13.8724 - mean_absolute_percentage_error: 40.8379 - val_loss: 237.0511 - val_mean_squared_error: 237.0511 - val_mean_absolute_error: 12.7239 - val_mean_absolute_percentage_error: 40.4686
# Epoch 12/400
#  - 0s - loss: 193.3828 - mean_squared_error: 193.3828 - mean_absolute_error: 11.6174 - mean_absolute_percentage_error: 34.3444 - val_loss: 228.9765 - val_mean_squared_error: 228.9765 - val_mean_absolute_error: 12.4184 - val_mean_absolute_percentage_error: 40.5134
# Epoch 13/400
#  - 0s - loss: 164.4347 - mean_squared_error: 164.4347 - mean_absolute_error: 10.7981 - mean_absolute_percentage_error: 32.1153 - val_loss: 229.4602 - val_mean_squared_error: 229.4602 - val_mean_absolute_error: 12.4056 - val_mean_absolute_percentage_error: 41.2947
# Epoch 14/400
#  - 0s - loss: 149.2822 - mean_squared_error: 149.2822 - mean_absolute_error: 10.3847 - mean_absolute_percentage_error: 31.1099 - val_loss: 230.8787 - val_mean_squared_error: 230.8787 - val_mean_absolute_error: 12.5206 - val_mean_absolute_percentage_error: 42.5876
# Epoch 15/400
#  - 0s - loss: 136.8209 - mean_squared_error: 136.8209 - mean_absolute_error: 10.0198 - mean_absolute_percentage_error: 30.3889 - val_loss: 220.8339 - val_mean_squared_error: 220.8339 - val_mean_absolute_error: 12.1974 - val_mean_absolute_percentage_error: 42.3474
# Epoch 16/400
#  - 0s - loss: 126.0453 - mean_squared_error: 126.0453 - mean_absolute_error: 9.5469 - mean_absolute_percentage_error: 29.1437 - val_loss: 216.0002 - val_mean_squared_error: 216.0002 - val_mean_absolute_error: 12.0461 - val_mean_absolute_percentage_error: 42.3035
# Epoch 17/400
#  - 0s - loss: 118.1498 - mean_squared_error: 118.1498 - mean_absolute_error: 9.2206 - mean_absolute_percentage_error: 28.4058 - val_loss: 209.7723 - val_mean_squared_error: 209.7723 - val_mean_absolute_error: 11.8676 - val_mean_absolute_percentage_error: 42.0778
# Epoch 18/400
#  - 0s - loss: 111.8395 - mean_squared_error: 111.8395 - mean_absolute_error: 8.9304 - mean_absolute_percentage_error: 27.5631 - val_loss: 201.1963 - val_mean_squared_error: 201.1963 - val_mean_absolute_error: 11.6252 - val_mean_absolute_percentage_error: 41.2161
# Epoch 19/400
#  - 0s - loss: 104.0104 - mean_squared_error: 104.0104 - mean_absolute_error: 8.5636 - mean_absolute_percentage_error: 26.6258 - val_loss: 203.8105 - val_mean_squared_error: 203.8105 - val_mean_absolute_error: 11.7563 - val_mean_absolute_percentage_error: 42.2231
# Epoch 20/400
#  - 0s - loss: 96.9807 - mean_squared_error: 96.9807 - mean_absolute_error: 8.2505 - mean_absolute_percentage_error: 25.8058 - val_loss: 199.1194 - val_mean_squared_error: 199.1194 - val_mean_absolute_error: 11.6374 - val_mean_absolute_percentage_error: 41.8411
# Epoch 21/400
#  - 0s - loss: 91.5168 - mean_squared_error: 91.5168 - mean_absolute_error: 8.0015 - mean_absolute_percentage_error: 24.9501 - val_loss: 186.6490 - val_mean_squared_error: 186.6490 - val_mean_absolute_error: 11.3158 - val_mean_absolute_percentage_error: 40.1713
# Epoch 22/400
#  - 0s - loss: 87.2653 - mean_squared_error: 87.2653 - mean_absolute_error: 7.8110 - mean_absolute_percentage_error: 24.2943 - val_loss: 181.3762 - val_mean_squared_error: 181.3762 - val_mean_absolute_error: 11.1702 - val_mean_absolute_percentage_error: 39.5553
# Epoch 23/400
#  - 0s - loss: 82.7564 - mean_squared_error: 82.7564 - mean_absolute_error: 7.5811 - mean_absolute_percentage_error: 23.6303 - val_loss: 179.6029 - val_mean_squared_error: 179.6029 - val_mean_absolute_error: 11.1027 - val_mean_absolute_percentage_error: 39.5088
# Epoch 24/400
#  - 0s - loss: 77.8459 - mean_squared_error: 77.8459 - mean_absolute_error: 7.2995 - mean_absolute_percentage_error: 22.8745 - val_loss: 178.0065 - val_mean_squared_error: 178.0065 - val_mean_absolute_error: 11.0403 - val_mean_absolute_percentage_error: 39.5532
# Epoch 25/400
#  - 0s - loss: 73.6420 - mean_squared_error: 73.6420 - mean_absolute_error: 7.0422 - mean_absolute_percentage_error: 22.2080 - val_loss: 176.3335 - val_mean_squared_error: 176.3335 - val_mean_absolute_error: 11.0092 - val_mean_absolute_percentage_error: 39.6612
# Epoch 26/400
#  - 0s - loss: 69.9520 - mean_squared_error: 69.9520 - mean_absolute_error: 6.8468 - mean_absolute_percentage_error: 21.6010 - val_loss: 169.2556 - val_mean_squared_error: 169.2556 - val_mean_absolute_error: 10.8208 - val_mean_absolute_percentage_error: 38.8038
# Epoch 27/400
#  - 0s - loss: 66.0847 - mean_squared_error: 66.0847 - mean_absolute_error: 6.6150 - mean_absolute_percentage_error: 20.9243 - val_loss: 167.9498 - val_mean_squared_error: 167.9498 - val_mean_absolute_error: 10.8066 - val_mean_absolute_percentage_error: 39.0464
# Epoch 28/400
#  - 0s - loss: 62.4222 - mean_squared_error: 62.4222 - mean_absolute_error: 6.4031 - mean_absolute_percentage_error: 20.3554 - val_loss: 163.0935 - val_mean_squared_error: 163.0935 - val_mean_absolute_error: 10.6422 - val_mean_absolute_percentage_error: 38.5420
# Epoch 29/400
#  - 0s - loss: 59.5167 - mean_squared_error: 59.5167 - mean_absolute_error: 6.2186 - mean_absolute_percentage_error: 19.8027 - val_loss: 159.8384 - val_mean_squared_error: 159.8384 - val_mean_absolute_error: 10.5805 - val_mean_absolute_percentage_error: 38.2484
# Epoch 30/400
#  - 0s - loss: 56.4657 - mean_squared_error: 56.4657 - mean_absolute_error: 6.0086 - mean_absolute_percentage_error: 19.1863 - val_loss: 159.3612 - val_mean_squared_error: 159.3612 - val_mean_absolute_error: 10.6324 - val_mean_absolute_percentage_error: 38.5309
# Epoch 31/400
#  - 0s - loss: 53.7924 - mean_squared_error: 53.7924 - mean_absolute_error: 5.8527 - mean_absolute_percentage_error: 18.6925 - val_loss: 153.4436 - val_mean_squared_error: 153.4436 - val_mean_absolute_error: 10.4526 - val_mean_absolute_percentage_error: 37.6872
# Epoch 32/400
#  - 0s - loss: 51.3715 - mean_squared_error: 51.3715 - mean_absolute_error: 5.7129 - mean_absolute_percentage_error: 18.2027 - val_loss: 149.6554 - val_mean_squared_error: 149.6554 - val_mean_absolute_error: 10.3273 - val_mean_absolute_percentage_error: 37.2301
# Epoch 33/400
#  - 0s - loss: 50.1762 - mean_squared_error: 50.1762 - mean_absolute_error: 5.5814 - mean_absolute_percentage_error: 17.9178 - val_loss: 151.1846 - val_mean_squared_error: 151.1846 - val_mean_absolute_error: 10.4341 - val_mean_absolute_percentage_error: 37.9157
# Epoch 34/400
#  - 0s - loss: 47.0693 - mean_squared_error: 47.0693 - mean_absolute_error: 5.3863 - mean_absolute_percentage_error: 17.3251 - val_loss: 145.0554 - val_mean_squared_error: 145.0554 - val_mean_absolute_error: 10.1894 - val_mean_absolute_percentage_error: 36.9935
# Epoch 35/400
#  - 0s - loss: 44.8265 - mean_squared_error: 44.8265 - mean_absolute_error: 5.2366 - mean_absolute_percentage_error: 16.8700 - val_loss: 143.4173 - val_mean_squared_error: 143.4173 - val_mean_absolute_error: 10.1633 - val_mean_absolute_percentage_error: 36.9412
# Epoch 36/400
#  - 0s - loss: 43.0423 - mean_squared_error: 43.0423 - mean_absolute_error: 5.1051 - mean_absolute_percentage_error: 16.4714 - val_loss: 140.5967 - val_mean_squared_error: 140.5967 - val_mean_absolute_error: 10.0770 - val_mean_absolute_percentage_error: 36.6816
# Epoch 37/400
#  - 0s - loss: 41.4186 - mean_squared_error: 41.4186 - mean_absolute_error: 4.9706 - mean_absolute_percentage_error: 16.1059 - val_loss: 138.4483 - val_mean_squared_error: 138.4483 - val_mean_absolute_error: 10.0436 - val_mean_absolute_percentage_error: 36.5591
# Epoch 38/400
#  - 0s - loss: 39.3971 - mean_squared_error: 39.3971 - mean_absolute_error: 4.8569 - mean_absolute_percentage_error: 15.6457 - val_loss: 132.4472 - val_mean_squared_error: 132.4472 - val_mean_absolute_error: 9.8007 - val_mean_absolute_percentage_error: 35.4277
# Epoch 39/400
#  - 0s - loss: 37.8273 - mean_squared_error: 37.8273 - mean_absolute_error: 4.7650 - mean_absolute_percentage_error: 15.3174 - val_loss: 130.2966 - val_mean_squared_error: 130.2966 - val_mean_absolute_error: 9.7688 - val_mean_absolute_percentage_error: 35.3176
# Epoch 40/400
#  - 0s - loss: 36.4134 - mean_squared_error: 36.4134 - mean_absolute_error: 4.6385 - mean_absolute_percentage_error: 14.9716 - val_loss: 129.4400 - val_mean_squared_error: 129.4400 - val_mean_absolute_error: 9.7885 - val_mean_absolute_percentage_error: 35.4536
# Epoch 41/400
#  - 0s - loss: 35.0892 - mean_squared_error: 35.0892 - mean_absolute_error: 4.5142 - mean_absolute_percentage_error: 14.6540 - val_loss: 126.9366 - val_mean_squared_error: 126.9366 - val_mean_absolute_error: 9.6860 - val_mean_absolute_percentage_error: 35.2141
# Epoch 42/400
#  - 0s - loss: 33.3893 - mean_squared_error: 33.3893 - mean_absolute_error: 4.4160 - mean_absolute_percentage_error: 14.2960 - val_loss: 122.0934 - val_mean_squared_error: 122.0934 - val_mean_absolute_error: 9.4801 - val_mean_absolute_percentage_error: 34.3213
# Epoch 43/400
#  - 0s - loss: 32.1190 - mean_squared_error: 32.1190 - mean_absolute_error: 4.3303 - mean_absolute_percentage_error: 14.0207 - val_loss: 119.5813 - val_mean_squared_error: 119.5813 - val_mean_absolute_error: 9.3810 - val_mean_absolute_percentage_error: 34.0468
# Epoch 44/400
#  - 0s - loss: 30.8231 - mean_squared_error: 30.8231 - mean_absolute_error: 4.2543 - mean_absolute_percentage_error: 13.7554 - val_loss: 115.4101 - val_mean_squared_error: 115.4101 - val_mean_absolute_error: 9.1727 - val_mean_absolute_percentage_error: 33.2440
# Epoch 45/400
#  - 0s - loss: 29.7959 - mean_squared_error: 29.7959 - mean_absolute_error: 4.2247 - mean_absolute_percentage_error: 13.5177 - val_loss: 110.4543 - val_mean_squared_error: 110.4543 - val_mean_absolute_error: 8.9972 - val_mean_absolute_percentage_error: 32.2371
# Epoch 46/400
#  - 0s - loss: 28.1336 - mean_squared_error: 28.1336 - mean_absolute_error: 4.0937 - mean_absolute_percentage_error: 13.1058 - val_loss: 109.4742 - val_mean_squared_error: 109.4742 - val_mean_absolute_error: 8.9859 - val_mean_absolute_percentage_error: 32.3539
# Epoch 47/400
#  - 0s - loss: 27.0867 - mean_squared_error: 27.0867 - mean_absolute_error: 4.0006 - mean_absolute_percentage_error: 12.9283 - val_loss: 107.5745 - val_mean_squared_error: 107.5745 - val_mean_absolute_error: 8.8898 - val_mean_absolute_percentage_error: 32.1807
# Epoch 48/400
#  - 0s - loss: 26.0235 - mean_squared_error: 26.0235 - mean_absolute_error: 3.9200 - mean_absolute_percentage_error: 12.6536 - val_loss: 102.9452 - val_mean_squared_error: 102.9452 - val_mean_absolute_error: 8.6239 - val_mean_absolute_percentage_error: 31.2386
# Epoch 49/400
#  - 0s - loss: 25.0542 - mean_squared_error: 25.0542 - mean_absolute_error: 3.8514 - mean_absolute_percentage_error: 12.4882 - val_loss: 101.6617 - val_mean_squared_error: 101.6617 - val_mean_absolute_error: 8.5889 - val_mean_absolute_percentage_error: 31.2574
# Epoch 50/400
#  - 0s - loss: 24.0198 - mean_squared_error: 24.0198 - mean_absolute_error: 3.7531 - mean_absolute_percentage_error: 12.1893 - val_loss: 96.9407 - val_mean_squared_error: 96.9407 - val_mean_absolute_error: 8.3436 - val_mean_absolute_percentage_error: 30.2508
# Epoch 51/400
#  - 0s - loss: 22.9889 - mean_squared_error: 22.9889 - mean_absolute_error: 3.7355 - mean_absolute_percentage_error: 11.9525 - val_loss: 92.3362 - val_mean_squared_error: 92.3362 - val_mean_absolute_error: 8.1307 - val_mean_absolute_percentage_error: 29.1668
# Epoch 52/400
#  - 0s - loss: 22.2724 - mean_squared_error: 22.2724 - mean_absolute_error: 3.6510 - mean_absolute_percentage_error: 11.7621 - val_loss: 92.6372 - val_mean_squared_error: 92.6372 - val_mean_absolute_error: 8.1852 - val_mean_absolute_percentage_error: 29.5717
# Epoch 53/400
#  - 0s - loss: 21.2478 - mean_squared_error: 21.2478 - mean_absolute_error: 3.6064 - mean_absolute_percentage_error: 11.4745 - val_loss: 87.8133 - val_mean_squared_error: 87.8133 - val_mean_absolute_error: 7.8026 - val_mean_absolute_percentage_error: 27.8779
# Epoch 54/400
#  - 0s - loss: 21.7995 - mean_squared_error: 21.7995 - mean_absolute_error: 3.7154 - mean_absolute_percentage_error: 11.5836 - val_loss: 85.8636 - val_mean_squared_error: 85.8636 - val_mean_absolute_error: 7.7790 - val_mean_absolute_percentage_error: 27.7898
# Epoch 55/400
#  - 0s - loss: 19.6440 - mean_squared_error: 19.6440 - mean_absolute_error: 3.4855 - mean_absolute_percentage_error: 11.1630 - val_loss: 87.3874 - val_mean_squared_error: 87.3874 - val_mean_absolute_error: 7.9047 - val_mean_absolute_percentage_error: 28.7204
# Epoch 56/400
#  - 0s - loss: 18.7147 - mean_squared_error: 18.7147 - mean_absolute_error: 3.3808 - mean_absolute_percentage_error: 11.0070 - val_loss: 84.8481 - val_mean_squared_error: 84.8481 - val_mean_absolute_error: 7.7820 - val_mean_absolute_percentage_error: 28.2070
# Epoch 57/400
#  - 0s - loss: 18.0517 - mean_squared_error: 18.0517 - mean_absolute_error: 3.3215 - mean_absolute_percentage_error: 10.7141 - val_loss: 80.6007 - val_mean_squared_error: 80.6007 - val_mean_absolute_error: 7.5719 - val_mean_absolute_percentage_error: 27.0982
# Epoch 58/400
#  - 0s - loss: 17.5374 - mean_squared_error: 17.5374 - mean_absolute_error: 3.2908 - mean_absolute_percentage_error: 10.5543 - val_loss: 79.7408 - val_mean_squared_error: 79.7408 - val_mean_absolute_error: 7.5157 - val_mean_absolute_percentage_error: 27.1129
# Epoch 59/400
#  - 0s - loss: 17.1337 - mean_squared_error: 17.1337 - mean_absolute_error: 3.2466 - mean_absolute_percentage_error: 10.5257 - val_loss: 78.2146 - val_mean_squared_error: 78.2146 - val_mean_absolute_error: 7.4507 - val_mean_absolute_percentage_error: 26.8926
# Epoch 60/400
#  - 0s - loss: 16.5032 - mean_squared_error: 16.5032 - mean_absolute_error: 3.1961 - mean_absolute_percentage_error: 10.2612 - val_loss: 73.3366 - val_mean_squared_error: 73.3366 - val_mean_absolute_error: 7.1772 - val_mean_absolute_percentage_error: 25.6426
# Epoch 61/400
#  - 0s - loss: 15.9123 - mean_squared_error: 15.9123 - mean_absolute_error: 3.1378 - mean_absolute_percentage_error: 9.9482 - val_loss: 71.3426 - val_mean_squared_error: 71.3426 - val_mean_absolute_error: 7.0611 - val_mean_absolute_percentage_error: 25.2150
# Epoch 62/400
#  - 0s - loss: 15.5424 - mean_squared_error: 15.5424 - mean_absolute_error: 3.0846 - mean_absolute_percentage_error: 9.9266 - val_loss: 71.7418 - val_mean_squared_error: 71.7418 - val_mean_absolute_error: 7.0507 - val_mean_absolute_percentage_error: 25.5785
# Epoch 63/400
#  - 0s - loss: 15.3067 - mean_squared_error: 15.3067 - mean_absolute_error: 3.0525 - mean_absolute_percentage_error: 9.9031 - val_loss: 69.0806 - val_mean_squared_error: 69.0806 - val_mean_absolute_error: 6.8991 - val_mean_absolute_percentage_error: 24.9049
# Epoch 64/400
#  - 0s - loss: 14.5056 - mean_squared_error: 14.5056 - mean_absolute_error: 3.0113 - mean_absolute_percentage_error: 9.5422 - val_loss: 65.0611 - val_mean_squared_error: 65.0611 - val_mean_absolute_error: 6.6831 - val_mean_absolute_percentage_error: 23.7242
# Epoch 65/400
#  - 0s - loss: 13.9157 - mean_squared_error: 13.9157 - mean_absolute_error: 2.9517 - mean_absolute_percentage_error: 9.3465 - val_loss: 64.7721 - val_mean_squared_error: 64.7721 - val_mean_absolute_error: 6.6462 - val_mean_absolute_percentage_error: 23.8504
# Epoch 66/400
#  - 0s - loss: 13.9647 - mean_squared_error: 13.9647 - mean_absolute_error: 2.9450 - mean_absolute_percentage_error: 9.5233 - val_loss: 65.0938 - val_mean_squared_error: 65.0938 - val_mean_absolute_error: 6.6324 - val_mean_absolute_percentage_error: 24.0849
# Epoch 67/400
#  - 0s - loss: 13.2880 - mean_squared_error: 13.2880 - mean_absolute_error: 2.8740 - mean_absolute_percentage_error: 9.2230 - val_loss: 59.7429 - val_mean_squared_error: 59.7429 - val_mean_absolute_error: 6.3067 - val_mean_absolute_percentage_error: 22.6128
# Epoch 68/400
#  - 0s - loss: 12.6989 - mean_squared_error: 12.6989 - mean_absolute_error: 2.8237 - mean_absolute_percentage_error: 8.9515 - val_loss: 57.8683 - val_mean_squared_error: 57.8683 - val_mean_absolute_error: 6.1681 - val_mean_absolute_percentage_error: 22.0649
# Epoch 69/400
#  - 0s - loss: 12.4562 - mean_squared_error: 12.4562 - mean_absolute_error: 2.7951 - mean_absolute_percentage_error: 8.8088 - val_loss: 56.4928 - val_mean_squared_error: 56.4928 - val_mean_absolute_error: 6.0681 - val_mean_absolute_percentage_error: 21.6950
# Epoch 70/400
#  - 0s - loss: 12.1205 - mean_squared_error: 12.1205 - mean_absolute_error: 2.7593 - mean_absolute_percentage_error: 8.7344 - val_loss: 56.0966 - val_mean_squared_error: 56.0966 - val_mean_absolute_error: 6.0417 - val_mean_absolute_percentage_error: 21.7139
# Epoch 71/400
#  - 0s - loss: 11.8119 - mean_squared_error: 11.8119 - mean_absolute_error: 2.7102 - mean_absolute_percentage_error: 8.6923 - val_loss: 55.7547 - val_mean_squared_error: 55.7547 - val_mean_absolute_error: 6.0036 - val_mean_absolute_percentage_error: 21.7459
# Epoch 72/400
#  - 0s - loss: 11.8272 - mean_squared_error: 11.8272 - mean_absolute_error: 2.7332 - mean_absolute_percentage_error: 8.6869 - val_loss: 53.4757 - val_mean_squared_error: 53.4757 - val_mean_absolute_error: 5.8591 - val_mean_absolute_percentage_error: 20.9656
# Epoch 73/400
#  - 0s - loss: 11.2904 - mean_squared_error: 11.2904 - mean_absolute_error: 2.6496 - mean_absolute_percentage_error: 8.4272 - val_loss: 53.4659 - val_mean_squared_error: 53.4659 - val_mean_absolute_error: 5.8844 - val_mean_absolute_percentage_error: 21.0595
# Epoch 74/400
#  - 0s - loss: 11.0670 - mean_squared_error: 11.0670 - mean_absolute_error: 2.6184 - mean_absolute_percentage_error: 8.3182 - val_loss: 51.7432 - val_mean_squared_error: 51.7432 - val_mean_absolute_error: 5.7617 - val_mean_absolute_percentage_error: 20.5158
# Epoch 75/400
#  - 0s - loss: 10.8912 - mean_squared_error: 10.8912 - mean_absolute_error: 2.6007 - mean_absolute_percentage_error: 8.2118 - val_loss: 50.5813 - val_mean_squared_error: 50.5813 - val_mean_absolute_error: 5.6800 - val_mean_absolute_percentage_error: 20.1518
# Epoch 76/400
#  - 0s - loss: 10.6320 - mean_squared_error: 10.6320 - mean_absolute_error: 2.5677 - mean_absolute_percentage_error: 8.0260 - val_loss: 49.4522 - val_mean_squared_error: 49.4522 - val_mean_absolute_error: 5.6044 - val_mean_absolute_percentage_error: 19.7889
# Epoch 77/400
#  - 0s - loss: 10.4971 - mean_squared_error: 10.4971 - mean_absolute_error: 2.5447 - mean_absolute_percentage_error: 8.0083 - val_loss: 49.5813 - val_mean_squared_error: 49.5813 - val_mean_absolute_error: 5.6103 - val_mean_absolute_percentage_error: 19.9460
# Epoch 78/400
#  - 0s - loss: 10.5573 - mean_squared_error: 10.5573 - mean_absolute_error: 2.5603 - mean_absolute_percentage_error: 8.1902 - val_loss: 49.8111 - val_mean_squared_error: 49.8111 - val_mean_absolute_error: 5.5985 - val_mean_absolute_percentage_error: 20.1496
# Epoch 79/400
#  - 0s - loss: 10.3300 - mean_squared_error: 10.3300 - mean_absolute_error: 2.5247 - mean_absolute_percentage_error: 7.9939 - val_loss: 47.5258 - val_mean_squared_error: 47.5258 - val_mean_absolute_error: 5.4368 - val_mean_absolute_percentage_error: 19.3292
# Epoch 80/400
#  - 0s - loss: 10.0346 - mean_squared_error: 10.0346 - mean_absolute_error: 2.4942 - mean_absolute_percentage_error: 7.9097 - val_loss: 47.8909 - val_mean_squared_error: 47.8909 - val_mean_absolute_error: 5.4819 - val_mean_absolute_percentage_error: 19.4639
# Epoch 81/400
#  - 0s - loss: 9.7912 - mean_squared_error: 9.7912 - mean_absolute_error: 2.4488 - mean_absolute_percentage_error: 7.7117 - val_loss: 45.4246 - val_mean_squared_error: 45.4246 - val_mean_absolute_error: 5.2993 - val_mean_absolute_percentage_error: 18.6115
# Epoch 82/400
#  - 0s - loss: 9.7351 - mean_squared_error: 9.7351 - mean_absolute_error: 2.4452 - mean_absolute_percentage_error: 7.5882 - val_loss: 44.6367 - val_mean_squared_error: 44.6367 - val_mean_absolute_error: 5.2447 - val_mean_absolute_percentage_error: 18.3581
# Epoch 83/400
#  - 0s - loss: 9.5717 - mean_squared_error: 9.5717 - mean_absolute_error: 2.4322 - mean_absolute_percentage_error: 7.5615 - val_loss: 44.3657 - val_mean_squared_error: 44.3657 - val_mean_absolute_error: 5.2068 - val_mean_absolute_percentage_error: 18.3111
# Epoch 84/400
#  - 0s - loss: 9.5601 - mean_squared_error: 9.5601 - mean_absolute_error: 2.4149 - mean_absolute_percentage_error: 7.4836 - val_loss: 42.6213 - val_mean_squared_error: 42.6213 - val_mean_absolute_error: 5.0537 - val_mean_absolute_percentage_error: 17.7885
# Epoch 85/400
#  - 0s - loss: 9.3646 - mean_squared_error: 9.3646 - mean_absolute_error: 2.3924 - mean_absolute_percentage_error: 7.4521 - val_loss: 42.3485 - val_mean_squared_error: 42.3485 - val_mean_absolute_error: 5.0333 - val_mean_absolute_percentage_error: 17.7842
# Epoch 86/400
#  - 0s - loss: 9.3338 - mean_squared_error: 9.3338 - mean_absolute_error: 2.3911 - mean_absolute_percentage_error: 7.4945 - val_loss: 42.3958 - val_mean_squared_error: 42.3958 - val_mean_absolute_error: 5.0382 - val_mean_absolute_percentage_error: 17.8093
# Epoch 87/400
#  - 0s - loss: 9.2340 - mean_squared_error: 9.2340 - mean_absolute_error: 2.3788 - mean_absolute_percentage_error: 7.4103 - val_loss: 41.7058 - val_mean_squared_error: 41.7058 - val_mean_absolute_error: 4.9882 - val_mean_absolute_percentage_error: 17.4860
# Epoch 88/400
#  - 0s - loss: 9.2001 - mean_squared_error: 9.2001 - mean_absolute_error: 2.3735 - mean_absolute_percentage_error: 7.3909 - val_loss: 41.7328 - val_mean_squared_error: 41.7328 - val_mean_absolute_error: 4.9885 - val_mean_absolute_percentage_error: 17.5257
# Epoch 89/400
#  - 0s - loss: 9.0509 - mean_squared_error: 9.0509 - mean_absolute_error: 2.3616 - mean_absolute_percentage_error: 7.3679 - val_loss: 41.1032 - val_mean_squared_error: 41.1032 - val_mean_absolute_error: 4.9319 - val_mean_absolute_percentage_error: 17.3366
# Epoch 90/400
#  - 0s - loss: 8.9688 - mean_squared_error: 8.9688 - mean_absolute_error: 2.3530 - mean_absolute_percentage_error: 7.3310 - val_loss: 40.7962 - val_mean_squared_error: 40.7962 - val_mean_absolute_error: 4.9031 - val_mean_absolute_percentage_error: 17.1981
# Epoch 91/400
#  - 0s - loss: 8.9211 - mean_squared_error: 8.9211 - mean_absolute_error: 2.3503 - mean_absolute_percentage_error: 7.3083 - val_loss: 40.2391 - val_mean_squared_error: 40.2391 - val_mean_absolute_error: 4.8566 - val_mean_absolute_percentage_error: 16.9734
# Epoch 92/400
#  - 0s - loss: 8.9243 - mean_squared_error: 8.9243 - mean_absolute_error: 2.3297 - mean_absolute_percentage_error: 7.1639 - val_loss: 39.2372 - val_mean_squared_error: 39.2372 - val_mean_absolute_error: 4.7618 - val_mean_absolute_percentage_error: 16.5288
# Epoch 93/400
#  - 0s - loss: 8.8026 - mean_squared_error: 8.8026 - mean_absolute_error: 2.3104 - mean_absolute_percentage_error: 7.1088 - val_loss: 39.7961 - val_mean_squared_error: 39.7961 - val_mean_absolute_error: 4.8171 - val_mean_absolute_percentage_error: 16.7783
# Epoch 94/400
#  - 0s - loss: 8.7476 - mean_squared_error: 8.7476 - mean_absolute_error: 2.3103 - mean_absolute_percentage_error: 7.0944 - val_loss: 39.2658 - val_mean_squared_error: 39.2658 - val_mean_absolute_error: 4.7684 - val_mean_absolute_percentage_error: 16.5013
# Epoch 95/400
#  - 0s - loss: 8.6704 - mean_squared_error: 8.6704 - mean_absolute_error: 2.3020 - mean_absolute_percentage_error: 7.0738 - val_loss: 39.6617 - val_mean_squared_error: 39.6617 - val_mean_absolute_error: 4.8008 - val_mean_absolute_percentage_error: 16.7510
# Epoch 96/400
#  - 0s - loss: 8.7472 - mean_squared_error: 8.7472 - mean_absolute_error: 2.3385 - mean_absolute_percentage_error: 7.2602 - val_loss: 39.2343 - val_mean_squared_error: 39.2343 - val_mean_absolute_error: 4.7609 - val_mean_absolute_percentage_error: 16.5780
# Epoch 97/400
#  - 0s - loss: 9.0271 - mean_squared_error: 9.0271 - mean_absolute_error: 2.3417 - mean_absolute_percentage_error: 7.1076 - val_loss: 37.3274 - val_mean_squared_error: 37.3274 - val_mean_absolute_error: 4.5893 - val_mean_absolute_percentage_error: 15.8235
# Epoch 98/400
#  - 0s - loss: 8.8627 - mean_squared_error: 8.8627 - mean_absolute_error: 2.3322 - mean_absolute_percentage_error: 7.1589 - val_loss: 38.0798 - val_mean_squared_error: 38.0798 - val_mean_absolute_error: 4.6739 - val_mean_absolute_percentage_error: 16.3170
# Epoch 99/400
#  - 0s - loss: 8.5184 - mean_squared_error: 8.5184 - mean_absolute_error: 2.2773 - mean_absolute_percentage_error: 6.9872 - val_loss: 36.1281 - val_mean_squared_error: 36.1281 - val_mean_absolute_error: 4.5014 - val_mean_absolute_percentage_error: 15.6078
# Epoch 100/400
#  - 0s - loss: 8.5249 - mean_squared_error: 8.5249 - mean_absolute_error: 2.2818 - mean_absolute_percentage_error: 7.0449 - val_loss: 37.0089 - val_mean_squared_error: 37.0089 - val_mean_absolute_error: 4.5982 - val_mean_absolute_percentage_error: 16.2035
# Epoch 101/400
#  - 0s - loss: 8.6493 - mean_squared_error: 8.6493 - mean_absolute_error: 2.3088 - mean_absolute_percentage_error: 7.2143 - val_loss: 37.0169 - val_mean_squared_error: 37.0169 - val_mean_absolute_error: 4.6071 - val_mean_absolute_percentage_error: 16.2668
# Epoch 102/400
#  - 0s - loss: 8.5106 - mean_squared_error: 8.5106 - mean_absolute_error: 2.2905 - mean_absolute_percentage_error: 7.1157 - val_loss: 36.0816 - val_mean_squared_error: 36.0816 - val_mean_absolute_error: 4.5118 - val_mean_absolute_percentage_error: 15.7618
# Epoch 103/400
#  - 0s - loss: 8.5034 - mean_squared_error: 8.5034 - mean_absolute_error: 2.2912 - mean_absolute_percentage_error: 7.1170 - val_loss: 37.0324 - val_mean_squared_error: 37.0324 - val_mean_absolute_error: 4.6050 - val_mean_absolute_percentage_error: 16.1531
# Epoch 104/400
#  - 0s - loss: 8.3011 - mean_squared_error: 8.3011 - mean_absolute_error: 2.2746 - mean_absolute_percentage_error: 7.0162 - val_loss: 35.4993 - val_mean_squared_error: 35.4993 - val_mean_absolute_error: 4.4534 - val_mean_absolute_percentage_error: 15.3948
# Epoch 105/400
#  - 0s - loss: 8.4274 - mean_squared_error: 8.4274 - mean_absolute_error: 2.2678 - mean_absolute_percentage_error: 6.8720 - val_loss: 35.0322 - val_mean_squared_error: 35.0322 - val_mean_absolute_error: 4.4073 - val_mean_absolute_percentage_error: 15.0729
# Epoch 106/400
#  - 0s - loss: 8.2190 - mean_squared_error: 8.2190 - mean_absolute_error: 2.2570 - mean_absolute_percentage_error: 6.9093 - val_loss: 36.3740 - val_mean_squared_error: 36.3740 - val_mean_absolute_error: 4.5328 - val_mean_absolute_percentage_error: 15.6603
# Epoch 107/400
#  - 0s - loss: 8.3135 - mean_squared_error: 8.3135 - mean_absolute_error: 2.2734 - mean_absolute_percentage_error: 6.9849 - val_loss: 35.8801 - val_mean_squared_error: 35.8801 - val_mean_absolute_error: 4.4898 - val_mean_absolute_percentage_error: 15.4594
# Epoch 108/400
#  - 0s - loss: 8.1549 - mean_squared_error: 8.1549 - mean_absolute_error: 2.2474 - mean_absolute_percentage_error: 6.8885 - val_loss: 34.8511 - val_mean_squared_error: 34.8511 - val_mean_absolute_error: 4.4107 - val_mean_absolute_percentage_error: 15.2357
# Epoch 109/400
#  - 0s - loss: 8.1240 - mean_squared_error: 8.1240 - mean_absolute_error: 2.2360 - mean_absolute_percentage_error: 6.8226 - val_loss: 34.2624 - val_mean_squared_error: 34.2624 - val_mean_absolute_error: 4.3559 - val_mean_absolute_percentage_error: 14.9385
# Epoch 110/400
#  - 0s - loss: 8.1867 - mean_squared_error: 8.1867 - mean_absolute_error: 2.2564 - mean_absolute_percentage_error: 6.8701 - val_loss: 34.1960 - val_mean_squared_error: 34.1960 - val_mean_absolute_error: 4.3444 - val_mean_absolute_percentage_error: 14.8589
# Epoch 111/400
#  - 0s - loss: 8.1528 - mean_squared_error: 8.1528 - mean_absolute_error: 2.2490 - mean_absolute_percentage_error: 6.8362 - val_loss: 33.7494 - val_mean_squared_error: 33.7494 - val_mean_absolute_error: 4.3089 - val_mean_absolute_percentage_error: 14.6742
# Epoch 112/400
#  - 0s - loss: 8.1198 - mean_squared_error: 8.1198 - mean_absolute_error: 2.2485 - mean_absolute_percentage_error: 6.8407 - val_loss: 34.1830 - val_mean_squared_error: 34.1830 - val_mean_absolute_error: 4.3489 - val_mean_absolute_percentage_error: 14.8797
# Epoch 113/400
#  - 0s - loss: 8.1808 - mean_squared_error: 8.1808 - mean_absolute_error: 2.2560 - mean_absolute_percentage_error: 6.8692 - val_loss: 34.3794 - val_mean_squared_error: 34.3794 - val_mean_absolute_error: 4.3682 - val_mean_absolute_percentage_error: 14.9746
# Epoch 114/400
#  - 0s - loss: 8.2514 - mean_squared_error: 8.2514 - mean_absolute_error: 2.2822 - mean_absolute_percentage_error: 7.0157 - val_loss: 35.6321 - val_mean_squared_error: 35.6321 - val_mean_absolute_error: 4.4696 - val_mean_absolute_percentage_error: 15.3760
# Epoch 115/400
#  - 0s - loss: 8.1055 - mean_squared_error: 8.1055 - mean_absolute_error: 2.2283 - mean_absolute_percentage_error: 6.8118 - val_loss: 33.4647 - val_mean_squared_error: 33.4647 - val_mean_absolute_error: 4.2926 - val_mean_absolute_percentage_error: 14.5610
# Epoch 116/400
#  - 0s - loss: 8.1971 - mean_squared_error: 8.1971 - mean_absolute_error: 2.2591 - mean_absolute_percentage_error: 6.8394 - val_loss: 33.2557 - val_mean_squared_error: 33.2557 - val_mean_absolute_error: 4.2753 - val_mean_absolute_percentage_error: 14.5153
# Epoch 117/400
#  - 0s - loss: 8.1117 - mean_squared_error: 8.1117 - mean_absolute_error: 2.2519 - mean_absolute_percentage_error: 6.8558 - val_loss: 33.9102 - val_mean_squared_error: 33.9102 - val_mean_absolute_error: 4.3313 - val_mean_absolute_percentage_error: 14.7785
# Epoch 118/400
#  - 0s - loss: 8.0662 - mean_squared_error: 8.0662 - mean_absolute_error: 2.2482 - mean_absolute_percentage_error: 6.8773 - val_loss: 34.5296 - val_mean_squared_error: 34.5296 - val_mean_absolute_error: 4.3885 - val_mean_absolute_percentage_error: 15.0787
# Epoch 119/400
#  - 0s - loss: 8.1091 - mean_squared_error: 8.1091 - mean_absolute_error: 2.2490 - mean_absolute_percentage_error: 6.9079 - val_loss: 34.3057 - val_mean_squared_error: 34.3057 - val_mean_absolute_error: 4.3676 - val_mean_absolute_percentage_error: 14.9419
# Epoch 120/400
#  - 0s - loss: 8.1175 - mean_squared_error: 8.1175 - mean_absolute_error: 2.2454 - mean_absolute_percentage_error: 6.8393 - val_loss: 33.0986 - val_mean_squared_error: 33.0986 - val_mean_absolute_error: 4.2743 - val_mean_absolute_percentage_error: 14.5191
# Epoch 121/400
#  - 0s - loss: 8.0558 - mean_squared_error: 8.0558 - mean_absolute_error: 2.2418 - mean_absolute_percentage_error: 6.8460 - val_loss: 34.0738 - val_mean_squared_error: 34.0738 - val_mean_absolute_error: 4.3511 - val_mean_absolute_percentage_error: 14.9139
# Epoch 122/400
#  - 0s - loss: 8.2403 - mean_squared_error: 8.2403 - mean_absolute_error: 2.2709 - mean_absolute_percentage_error: 6.8755 - val_loss: 32.4829 - val_mean_squared_error: 32.4829 - val_mean_absolute_error: 4.2187 - val_mean_absolute_percentage_error: 14.2721
# Epoch 123/400
#  - 0s - loss: 8.0149 - mean_squared_error: 8.0149 - mean_absolute_error: 2.2517 - mean_absolute_percentage_error: 6.8729 - val_loss: 33.7791 - val_mean_squared_error: 33.7791 - val_mean_absolute_error: 4.3267 - val_mean_absolute_percentage_error: 14.8211
# Epoch 124/400
#  - 0s - loss: 8.2594 - mean_squared_error: 8.2594 - mean_absolute_error: 2.2634 - mean_absolute_percentage_error: 6.8783 - val_loss: 32.0513 - val_mean_squared_error: 32.0513 - val_mean_absolute_error: 4.1856 - val_mean_absolute_percentage_error: 14.0617
# Epoch 125/400
#  - 0s - loss: 8.2566 - mean_squared_error: 8.2566 - mean_absolute_error: 2.2474 - mean_absolute_percentage_error: 6.7504 - val_loss: 32.1976 - val_mean_squared_error: 32.1976 - val_mean_absolute_error: 4.2120 - val_mean_absolute_percentage_error: 14.3435
# Epoch 126/400
#  - 0s - loss: 8.0346 - mean_squared_error: 8.0346 - mean_absolute_error: 2.2299 - mean_absolute_percentage_error: 6.8188 - val_loss: 33.0094 - val_mean_squared_error: 33.0094 - val_mean_absolute_error: 4.2754 - val_mean_absolute_percentage_error: 14.7256
# Epoch 127/400
#  - 0s - loss: 7.9698 - mean_squared_error: 7.9698 - mean_absolute_error: 2.2236 - mean_absolute_percentage_error: 6.8146 - val_loss: 32.5988 - val_mean_squared_error: 32.5988 - val_mean_absolute_error: 4.2486 - val_mean_absolute_percentage_error: 14.5688
# Epoch 128/400
#  - 0s - loss: 7.9436 - mean_squared_error: 7.9436 - mean_absolute_error: 2.2239 - mean_absolute_percentage_error: 6.7619 - val_loss: 32.2493 - val_mean_squared_error: 32.2493 - val_mean_absolute_error: 4.2154 - val_mean_absolute_percentage_error: 14.3068
# Epoch 129/400
#  - 0s - loss: 8.1053 - mean_squared_error: 8.1053 - mean_absolute_error: 2.2344 - mean_absolute_percentage_error: 6.7539 - val_loss: 32.7828 - val_mean_squared_error: 32.7828 - val_mean_absolute_error: 4.2560 - val_mean_absolute_percentage_error: 14.4536
# Epoch 130/400
#  - 0s - loss: 7.8765 - mean_squared_error: 7.8765 - mean_absolute_error: 2.2252 - mean_absolute_percentage_error: 6.7854 - val_loss: 34.0848 - val_mean_squared_error: 34.0848 - val_mean_absolute_error: 4.3644 - val_mean_absolute_percentage_error: 14.9636
# Epoch 131/400
#  - 0s - loss: 8.0838 - mean_squared_error: 8.0838 - mean_absolute_error: 2.2439 - mean_absolute_percentage_error: 6.9083 - val_loss: 33.8092 - val_mean_squared_error: 33.8092 - val_mean_absolute_error: 4.3509 - val_mean_absolute_percentage_error: 15.0512
# Epoch 132/400
#  - 0s - loss: 8.0117 - mean_squared_error: 8.0117 - mean_absolute_error: 2.2125 - mean_absolute_percentage_error: 6.7646 - val_loss: 32.4312 - val_mean_squared_error: 32.4312 - val_mean_absolute_error: 4.2376 - val_mean_absolute_percentage_error: 14.5102
# Epoch 133/400
#  - 0s - loss: 8.0378 - mean_squared_error: 8.0378 - mean_absolute_error: 2.2250 - mean_absolute_percentage_error: 6.7556 - val_loss: 32.0253 - val_mean_squared_error: 32.0253 - val_mean_absolute_error: 4.2085 - val_mean_absolute_percentage_error: 14.4297
# Epoch 134/400
#  - 0s - loss: 8.0116 - mean_squared_error: 8.0116 - mean_absolute_error: 2.2339 - mean_absolute_percentage_error: 6.8689 - val_loss: 33.5890 - val_mean_squared_error: 33.5890 - val_mean_absolute_error: 4.3494 - val_mean_absolute_percentage_error: 15.1833
# Epoch 135/400
#  - 0s - loss: 8.2429 - mean_squared_error: 8.2429 - mean_absolute_error: 2.2406 - mean_absolute_percentage_error: 6.8231 - val_loss: 30.9147 - val_mean_squared_error: 30.9147 - val_mean_absolute_error: 4.1267 - val_mean_absolute_percentage_error: 14.1421
# Epoch 136/400
#  - 0s - loss: 7.9257 - mean_squared_error: 7.9257 - mean_absolute_error: 2.2167 - mean_absolute_percentage_error: 6.7749 - val_loss: 32.5079 - val_mean_squared_error: 32.5079 - val_mean_absolute_error: 4.2499 - val_mean_absolute_percentage_error: 14.6984
# Epoch 137/400
#  - 0s - loss: 7.9412 - mean_squared_error: 7.9412 - mean_absolute_error: 2.2207 - mean_absolute_percentage_error: 6.7963 - val_loss: 31.3777 - val_mean_squared_error: 31.3777 - val_mean_absolute_error: 4.1598 - val_mean_absolute_percentage_error: 14.1929
# Epoch 138/400
#  - 0s - loss: 7.9844 - mean_squared_error: 7.9844 - mean_absolute_error: 2.2260 - mean_absolute_percentage_error: 6.7529 - val_loss: 31.9900 - val_mean_squared_error: 31.9900 - val_mean_absolute_error: 4.2104 - val_mean_absolute_percentage_error: 14.4254
# Epoch 139/400
#  - 0s - loss: 7.8628 - mean_squared_error: 7.8628 - mean_absolute_error: 2.2100 - mean_absolute_percentage_error: 6.7558 - val_loss: 32.4406 - val_mean_squared_error: 32.4406 - val_mean_absolute_error: 4.2463 - val_mean_absolute_percentage_error: 14.6032
# Epoch 140/400
#  - 0s - loss: 7.9858 - mean_squared_error: 7.9858 - mean_absolute_error: 2.2243 - mean_absolute_percentage_error: 6.7770 - val_loss: 31.7665 - val_mean_squared_error: 31.7665 - val_mean_absolute_error: 4.1948 - val_mean_absolute_percentage_error: 14.3595
# Epoch 141/400
#  - 0s - loss: 7.8394 - mean_squared_error: 7.8394 - mean_absolute_error: 2.2154 - mean_absolute_percentage_error: 6.7359 - val_loss: 31.7958 - val_mean_squared_error: 31.7958 - val_mean_absolute_error: 4.1848 - val_mean_absolute_percentage_error: 14.2551
# Epoch 142/400
#  - 0s - loss: 7.9209 - mean_squared_error: 7.9209 - mean_absolute_error: 2.2256 - mean_absolute_percentage_error: 6.7439 - val_loss: 32.0857 - val_mean_squared_error: 32.0857 - val_mean_absolute_error: 4.2018 - val_mean_absolute_percentage_error: 14.2527
# Epoch 143/400
#  - 0s - loss: 7.9352 - mean_squared_error: 7.9352 - mean_absolute_error: 2.2403 - mean_absolute_percentage_error: 6.8203 - val_loss: 32.9641 - val_mean_squared_error: 32.9641 - val_mean_absolute_error: 4.2723 - val_mean_absolute_percentage_error: 14.5474
# Epoch 144/400
#  - 0s - loss: 7.8968 - mean_squared_error: 7.8968 - mean_absolute_error: 2.2320 - mean_absolute_percentage_error: 6.8014 - val_loss: 31.8657 - val_mean_squared_error: 31.8657 - val_mean_absolute_error: 4.1925 - val_mean_absolute_percentage_error: 14.2712
# Epoch 145/400
#  - 0s - loss: 7.8545 - mean_squared_error: 7.8545 - mean_absolute_error: 2.2134 - mean_absolute_percentage_error: 6.7367 - val_loss: 32.0771 - val_mean_squared_error: 32.0771 - val_mean_absolute_error: 4.2160 - val_mean_absolute_percentage_error: 14.3696
# Epoch 146/400
#  - 0s - loss: 7.9155 - mean_squared_error: 7.9155 - mean_absolute_error: 2.2168 - mean_absolute_percentage_error: 6.7327 - val_loss: 32.2920 - val_mean_squared_error: 32.2920 - val_mean_absolute_error: 4.2316 - val_mean_absolute_percentage_error: 14.4261
# Epoch 147/400
#  - 0s - loss: 7.8571 - mean_squared_error: 7.8571 - mean_absolute_error: 2.2135 - mean_absolute_percentage_error: 6.7620 - val_loss: 32.4829 - val_mean_squared_error: 32.4829 - val_mean_absolute_error: 4.2522 - val_mean_absolute_percentage_error: 14.5469
# Epoch 148/400
#  - 0s - loss: 7.9555 - mean_squared_error: 7.9555 - mean_absolute_error: 2.2113 - mean_absolute_percentage_error: 6.7269 - val_loss: 31.5440 - val_mean_squared_error: 31.5440 - val_mean_absolute_error: 4.1814 - val_mean_absolute_percentage_error: 14.2408
# Epoch 149/400
#  - 0s - loss: 7.8478 - mean_squared_error: 7.8478 - mean_absolute_error: 2.2013 - mean_absolute_percentage_error: 6.7418 - val_loss: 32.7944 - val_mean_squared_error: 32.7944 - val_mean_absolute_error: 4.2898 - val_mean_absolute_percentage_error: 14.7912
# Epoch 150/400
#  - 0s - loss: 7.9136 - mean_squared_error: 7.9136 - mean_absolute_error: 2.2228 - mean_absolute_percentage_error: 6.8366 - val_loss: 32.1626 - val_mean_squared_error: 32.1626 - val_mean_absolute_error: 4.2362 - val_mean_absolute_percentage_error: 14.5266
# Epoch 151/400
#  - 0s - loss: 7.8964 - mean_squared_error: 7.8964 - mean_absolute_error: 2.2169 - mean_absolute_percentage_error: 6.7561 - val_loss: 31.1875 - val_mean_squared_error: 31.1875 - val_mean_absolute_error: 4.1556 - val_mean_absolute_percentage_error: 14.1294
# Epoch 152/400
#  - 0s - loss: 7.8881 - mean_squared_error: 7.8881 - mean_absolute_error: 2.2149 - mean_absolute_percentage_error: 6.7283 - val_loss: 31.8122 - val_mean_squared_error: 31.8122 - val_mean_absolute_error: 4.2025 - val_mean_absolute_percentage_error: 14.3157
# Epoch 153/400
#  - 0s - loss: 7.9475 - mean_squared_error: 7.9475 - mean_absolute_error: 2.2229 - mean_absolute_percentage_error: 6.7479 - val_loss: 31.7594 - val_mean_squared_error: 31.7594 - val_mean_absolute_error: 4.2021 - val_mean_absolute_percentage_error: 14.3285
# Epoch 154/400
#  - 0s - loss: 7.8330 - mean_squared_error: 7.8330 - mean_absolute_error: 2.2133 - mean_absolute_percentage_error: 6.7449 - val_loss: 31.7357 - val_mean_squared_error: 31.7357 - val_mean_absolute_error: 4.1956 - val_mean_absolute_percentage_error: 14.2813
# Epoch 155/400
#  - 0s - loss: 7.8572 - mean_squared_error: 7.8572 - mean_absolute_error: 2.2218 - mean_absolute_percentage_error: 6.7674 - val_loss: 31.9217 - val_mean_squared_error: 31.9217 - val_mean_absolute_error: 4.2143 - val_mean_absolute_percentage_error: 14.3948
# Epoch 156/400
#  - 0s - loss: 8.0608 - mean_squared_error: 8.0608 - mean_absolute_error: 2.2537 - mean_absolute_percentage_error: 6.9238 - val_loss: 31.7921 - val_mean_squared_error: 31.7921 - val_mean_absolute_error: 4.2200 - val_mean_absolute_percentage_error: 14.5154
# Epoch 157/400
#  - 0s - loss: 7.8732 - mean_squared_error: 7.8732 - mean_absolute_error: 2.2012 - mean_absolute_percentage_error: 6.7141 - val_loss: 30.3780 - val_mean_squared_error: 30.3780 - val_mean_absolute_error: 4.1004 - val_mean_absolute_percentage_error: 13.9006
# Epoch 158/400
#  - 0s - loss: 9.3946 - mean_squared_error: 9.3946 - mean_absolute_error: 2.3920 - mean_absolute_percentage_error: 7.0436 - val_loss: 30.6230 - val_mean_squared_error: 30.6230 - val_mean_absolute_error: 4.1172 - val_mean_absolute_percentage_error: 13.7990
# Epoch 159/400
#  - 0s - loss: 8.1955 - mean_squared_error: 8.1955 - mean_absolute_error: 2.2932 - mean_absolute_percentage_error: 7.0161 - val_loss: 34.3887 - val_mean_squared_error: 34.3887 - val_mean_absolute_error: 4.4528 - val_mean_absolute_percentage_error: 15.4649
# Epoch 160/400
#  - 0s - loss: 7.9569 - mean_squared_error: 7.9569 - mean_absolute_error: 2.2343 - mean_absolute_percentage_error: 6.8870 - val_loss: 31.1604 - val_mean_squared_error: 31.1604 - val_mean_absolute_error: 4.1638 - val_mean_absolute_percentage_error: 14.1483
# Epoch 161/400
#  - 0s - loss: 7.8847 - mean_squared_error: 7.8847 - mean_absolute_error: 2.2180 - mean_absolute_percentage_error: 6.7382 - val_loss: 31.5086 - val_mean_squared_error: 31.5086 - val_mean_absolute_error: 4.1844 - val_mean_absolute_percentage_error: 14.2069
# Epoch 162/400
#  - 0s - loss: 7.9844 - mean_squared_error: 7.9844 - mean_absolute_error: 2.2490 - mean_absolute_percentage_error: 6.8773 - val_loss: 32.1832 - val_mean_squared_error: 32.1832 - val_mean_absolute_error: 4.2275 - val_mean_absolute_percentage_error: 14.4551
# Epoch 163/400
#  - 0s - loss: 7.8925 - mean_squared_error: 7.8925 - mean_absolute_error: 2.2289 - mean_absolute_percentage_error: 6.7740 - val_loss: 30.0792 - val_mean_squared_error: 30.0792 - val_mean_absolute_error: 4.0588 - val_mean_absolute_percentage_error: 13.6691
# Epoch 164/400
#  - 0s - loss: 8.0473 - mean_squared_error: 8.0473 - mean_absolute_error: 2.2300 - mean_absolute_percentage_error: 6.7166 - val_loss: 30.3652 - val_mean_squared_error: 30.3652 - val_mean_absolute_error: 4.0915 - val_mean_absolute_percentage_error: 13.8488
# Epoch 165/400
#  - 0s - loss: 7.9656 - mean_squared_error: 7.9656 - mean_absolute_error: 2.2257 - mean_absolute_percentage_error: 6.7319 - val_loss: 30.3005 - val_mean_squared_error: 30.3005 - val_mean_absolute_error: 4.1039 - val_mean_absolute_percentage_error: 14.0223
# Epoch 166/400
#  - 0s - loss: 7.9409 - mean_squared_error: 7.9409 - mean_absolute_error: 2.2187 - mean_absolute_percentage_error: 6.8251 - val_loss: 32.3288 - val_mean_squared_error: 32.3288 - val_mean_absolute_error: 4.2617 - val_mean_absolute_percentage_error: 14.7171
# Epoch 167/400
#  - 0s - loss: 7.8236 - mean_squared_error: 7.8236 - mean_absolute_error: 2.2050 - mean_absolute_percentage_error: 6.7187 - val_loss: 30.0325 - val_mean_squared_error: 30.0325 - val_mean_absolute_error: 4.0730 - val_mean_absolute_percentage_error: 13.8199
# Epoch 168/400
#  - 0s - loss: 7.8753 - mean_squared_error: 7.8753 - mean_absolute_error: 2.2301 - mean_absolute_percentage_error: 6.7853 - val_loss: 31.8341 - val_mean_squared_error: 31.8341 - val_mean_absolute_error: 4.2102 - val_mean_absolute_percentage_error: 14.3896
# Epoch 169/400
#  - 0s - loss: 7.7056 - mean_squared_error: 7.7056 - mean_absolute_error: 2.2001 - mean_absolute_percentage_error: 6.7002 - val_loss: 30.5254 - val_mean_squared_error: 30.5254 - val_mean_absolute_error: 4.1034 - val_mean_absolute_percentage_error: 13.8409
# Epoch 170/400
#  - 0s - loss: 8.3617 - mean_squared_error: 8.3617 - mean_absolute_error: 2.2639 - mean_absolute_percentage_error: 6.7372 - val_loss: 30.7675 - val_mean_squared_error: 30.7675 - val_mean_absolute_error: 4.1151 - val_mean_absolute_percentage_error: 13.7945
# Epoch 171/400
#  - 0s - loss: 7.9686 - mean_squared_error: 7.9686 - mean_absolute_error: 2.2240 - mean_absolute_percentage_error: 6.7219 - val_loss: 33.4908 - val_mean_squared_error: 33.4908 - val_mean_absolute_error: 4.3510 - val_mean_absolute_percentage_error: 14.8818
# Epoch 172/400
#  - 0s - loss: 7.9450 - mean_squared_error: 7.9450 - mean_absolute_error: 2.2354 - mean_absolute_percentage_error: 6.8724 - val_loss: 32.9238 - val_mean_squared_error: 32.9238 - val_mean_absolute_error: 4.3074 - val_mean_absolute_percentage_error: 14.7161
# Epoch 173/400
#  - 0s - loss: 8.1459 - mean_squared_error: 8.1459 - mean_absolute_error: 2.2339 - mean_absolute_percentage_error: 6.7486 - val_loss: 30.7636 - val_mean_squared_error: 30.7636 - val_mean_absolute_error: 4.1186 - val_mean_absolute_percentage_error: 13.8256
# Epoch 174/400
#  - 0s - loss: 7.8885 - mean_squared_error: 7.8885 - mean_absolute_error: 2.2146 - mean_absolute_percentage_error: 6.6683 - val_loss: 32.3721 - val_mean_squared_error: 32.3721 - val_mean_absolute_error: 4.2583 - val_mean_absolute_percentage_error: 14.5252
# Epoch 175/400
#  - 0s - loss: 7.7987 - mean_squared_error: 7.7987 - mean_absolute_error: 2.2044 - mean_absolute_percentage_error: 6.7344 - val_loss: 31.7794 - val_mean_squared_error: 31.7794 - val_mean_absolute_error: 4.2178 - val_mean_absolute_percentage_error: 14.4085
# Epoch 176/400
#  - 0s - loss: 7.7631 - mean_squared_error: 7.7631 - mean_absolute_error: 2.2024 - mean_absolute_percentage_error: 6.7174 - val_loss: 32.1514 - val_mean_squared_error: 32.1514 - val_mean_absolute_error: 4.2419 - val_mean_absolute_percentage_error: 14.4737
# Epoch 177/400
#  - 0s - loss: 7.8270 - mean_squared_error: 7.8270 - mean_absolute_error: 2.2076 - mean_absolute_percentage_error: 6.7048 - val_loss: 31.0812 - val_mean_squared_error: 31.0812 - val_mean_absolute_error: 4.1582 - val_mean_absolute_percentage_error: 14.1606
# Epoch 178/400
# ...
# Epoch 342/400
#  - 0s - loss: 7.5309 - mean_squared_error: 7.5309 - mean_absolute_error: 2.1619 - mean_absolute_percentage_error: 6.5955 - val_loss: 29.0901 - val_mean_squared_error: 29.0901 - val_mean_absolute_error: 4.0721 - val_mean_absolute_percentage_error: 13.7664
# Epoch 343/400
#  - 0s - loss: 7.4889 - mean_squared_error: 7.4889 - mean_absolute_error: 2.1443 - mean_absolute_percentage_error: 6.5068 - val_loss: 29.0680 - val_mean_squared_error: 29.0680 - val_mean_absolute_error: 4.0730 - val_mean_absolute_percentage_error: 13.7917
# Epoch 344/400
#  - 0s - loss: 7.6737 - mean_squared_error: 7.6737 - mean_absolute_error: 2.1669 - mean_absolute_percentage_error: 6.6057 - val_loss: 28.8899 - val_mean_squared_error: 28.8899 - val_mean_absolute_error: 4.0501 - val_mean_absolute_percentage_error: 13.6790
# Epoch 345/400
#  - 0s - loss: 7.6525 - mean_squared_error: 7.6525 - mean_absolute_error: 2.1543 - mean_absolute_percentage_error: 6.4640 - val_loss: 28.3301 - val_mean_squared_error: 28.3301 - val_mean_absolute_error: 3.9830 - val_mean_absolute_percentage_error: 13.3367
# Epoch 346/400
#  - 0s - loss: 7.4907 - mean_squared_error: 7.4907 - mean_absolute_error: 2.1542 - mean_absolute_percentage_error: 6.5564 - val_loss: 30.6140 - val_mean_squared_error: 30.6140 - val_mean_absolute_error: 4.1926 - val_mean_absolute_percentage_error: 14.2514
# Epoch 347/400
#  - 0s - loss: 7.5612 - mean_squared_error: 7.5612 - mean_absolute_error: 2.1712 - mean_absolute_percentage_error: 6.6495 - val_loss: 29.7995 - val_mean_squared_error: 29.7995 - val_mean_absolute_error: 4.1188 - val_mean_absolute_percentage_error: 13.9140
# Epoch 348/400
#  - 0s - loss: 7.5009 - mean_squared_error: 7.5009 - mean_absolute_error: 2.1385 - mean_absolute_percentage_error: 6.4719 - val_loss: 28.6889 - val_mean_squared_error: 28.6889 - val_mean_absolute_error: 4.0206 - val_mean_absolute_percentage_error: 13.4776
# Epoch 349/400
#  - 0s - loss: 7.6094 - mean_squared_error: 7.6094 - mean_absolute_error: 2.1535 - mean_absolute_percentage_error: 6.5039 - val_loss: 29.0877 - val_mean_squared_error: 29.0877 - val_mean_absolute_error: 4.0635 - val_mean_absolute_percentage_error: 13.6710
# Epoch 350/400
#  - 0s - loss: 7.6445 - mean_squared_error: 7.6445 - mean_absolute_error: 2.1542 - mean_absolute_percentage_error: 6.5021 - val_loss: 29.0265 - val_mean_squared_error: 29.0265 - val_mean_absolute_error: 4.0149 - val_mean_absolute_percentage_error: 13.4306
# Epoch 351/400
#  - 0s - loss: 7.7891 - mean_squared_error: 7.7891 - mean_absolute_error: 2.1807 - mean_absolute_percentage_error: 6.6036 - val_loss: 28.7068 - val_mean_squared_error: 28.7068 - val_mean_absolute_error: 4.0098 - val_mean_absolute_percentage_error: 13.4987
# Epoch 352/400
#  - 0s - loss: 7.5122 - mean_squared_error: 7.5122 - mean_absolute_error: 2.1319 - mean_absolute_percentage_error: 6.4315 - val_loss: 28.0092 - val_mean_squared_error: 28.0092 - val_mean_absolute_error: 3.9382 - val_mean_absolute_percentage_error: 13.0766
# Epoch 353/400
#  - 0s - loss: 7.7614 - mean_squared_error: 7.7614 - mean_absolute_error: 2.1690 - mean_absolute_percentage_error: 6.5423 - val_loss: 29.8641 - val_mean_squared_error: 29.8641 - val_mean_absolute_error: 4.1122 - val_mean_absolute_percentage_error: 13.8076
# Epoch 354/400
#  - 0s - loss: 7.5843 - mean_squared_error: 7.5843 - mean_absolute_error: 2.1392 - mean_absolute_percentage_error: 6.4366 - val_loss: 29.2466 - val_mean_squared_error: 29.2466 - val_mean_absolute_error: 4.0220 - val_mean_absolute_percentage_error: 13.3306
# Epoch 355/400
#  - 0s - loss: 7.4517 - mean_squared_error: 7.4517 - mean_absolute_error: 2.1423 - mean_absolute_percentage_error: 6.4592 - val_loss: 30.7368 - val_mean_squared_error: 30.7368 - val_mean_absolute_error: 4.1770 - val_mean_absolute_percentage_error: 14.1543
# Epoch 356/400
#  - 0s - loss: 7.8158 - mean_squared_error: 7.8158 - mean_absolute_error: 2.2130 - mean_absolute_percentage_error: 6.8142 - val_loss: 30.5958 - val_mean_squared_error: 30.5958 - val_mean_absolute_error: 4.1896 - val_mean_absolute_percentage_error: 14.3010
# Epoch 357/400
#  - 0s - loss: 7.8338 - mean_squared_error: 7.8338 - mean_absolute_error: 2.1934 - mean_absolute_percentage_error: 6.5990 - val_loss: 28.3485 - val_mean_squared_error: 28.3485 - val_mean_absolute_error: 3.9777 - val_mean_absolute_percentage_error: 13.2797
# Epoch 358/400
#  - 0s - loss: 7.5189 - mean_squared_error: 7.5189 - mean_absolute_error: 2.1516 - mean_absolute_percentage_error: 6.4884 - val_loss: 29.3838 - val_mean_squared_error: 29.3838 - val_mean_absolute_error: 4.0915 - val_mean_absolute_percentage_error: 13.8885
# Epoch 359/400
#  - 0s - loss: 7.6914 - mean_squared_error: 7.6914 - mean_absolute_error: 2.1609 - mean_absolute_percentage_error: 6.5465 - val_loss: 29.6930 - val_mean_squared_error: 29.6930 - val_mean_absolute_error: 4.1207 - val_mean_absolute_percentage_error: 14.0135
# Epoch 360/400
#  - 0s - loss: 7.5951 - mean_squared_error: 7.5951 - mean_absolute_error: 2.1592 - mean_absolute_percentage_error: 6.5404 - val_loss: 29.7600 - val_mean_squared_error: 29.7600 - val_mean_absolute_error: 4.1027 - val_mean_absolute_percentage_error: 13.8706
# Epoch 361/400
#  - 0s - loss: 7.5046 - mean_squared_error: 7.5046 - mean_absolute_error: 2.1523 - mean_absolute_percentage_error: 6.5272 - val_loss: 29.3361 - val_mean_squared_error: 29.3361 - val_mean_absolute_error: 4.0709 - val_mean_absolute_percentage_error: 13.7915
# Epoch 362/400
#  - 0s - loss: 7.7094 - mean_squared_error: 7.7094 - mean_absolute_error: 2.1854 - mean_absolute_percentage_error: 6.6990 - val_loss: 29.1291 - val_mean_squared_error: 29.1291 - val_mean_absolute_error: 4.0646 - val_mean_absolute_percentage_error: 13.7926
# Epoch 363/400
#  - 0s - loss: 7.4800 - mean_squared_error: 7.4800 - mean_absolute_error: 2.1505 - mean_absolute_percentage_error: 6.5482 - val_loss: 29.1901 - val_mean_squared_error: 29.1901 - val_mean_absolute_error: 4.0754 - val_mean_absolute_percentage_error: 13.7960
# Epoch 364/400
#  - 0s - loss: 7.6417 - mean_squared_error: 7.6417 - mean_absolute_error: 2.1595 - mean_absolute_percentage_error: 6.5176 - val_loss: 28.9760 - val_mean_squared_error: 28.9760 - val_mean_absolute_error: 4.0291 - val_mean_absolute_percentage_error: 13.5268
# Epoch 365/400
#  - 0s - loss: 7.5274 - mean_squared_error: 7.5274 - mean_absolute_error: 2.1402 - mean_absolute_percentage_error: 6.4701 - val_loss: 29.5173 - val_mean_squared_error: 29.5173 - val_mean_absolute_error: 4.0655 - val_mean_absolute_percentage_error: 13.6734
# Epoch 366/400
#  - 0s - loss: 7.5626 - mean_squared_error: 7.5626 - mean_absolute_error: 2.1568 - mean_absolute_percentage_error: 6.5006 - val_loss: 28.5953 - val_mean_squared_error: 28.5953 - val_mean_absolute_error: 3.9728 - val_mean_absolute_percentage_error: 13.2048
# Epoch 367/400
#  - 0s - loss: 7.6394 - mean_squared_error: 7.6394 - mean_absolute_error: 2.1506 - mean_absolute_percentage_error: 6.4380 - val_loss: 29.1407 - val_mean_squared_error: 29.1407 - val_mean_absolute_error: 4.0437 - val_mean_absolute_percentage_error: 13.5887
# Epoch 368/400
#  - 0s - loss: 7.4251 - mean_squared_error: 7.4251 - mean_absolute_error: 2.1356 - mean_absolute_percentage_error: 6.4882 - val_loss: 30.5155 - val_mean_squared_error: 30.5155 - val_mean_absolute_error: 4.1930 - val_mean_absolute_percentage_error: 14.3435
# Epoch 369/400
#  - 0s - loss: 7.7565 - mean_squared_error: 7.7565 - mean_absolute_error: 2.1873 - mean_absolute_percentage_error: 6.7454 - val_loss: 30.0403 - val_mean_squared_error: 30.0403 - val_mean_absolute_error: 4.1753 - val_mean_absolute_percentage_error: 14.3271
# Epoch 370/400
#  - 0s - loss: 7.7154 - mean_squared_error: 7.7154 - mean_absolute_error: 2.1636 - mean_absolute_percentage_error: 6.5394 - val_loss: 29.2800 - val_mean_squared_error: 29.2800 - val_mean_absolute_error: 4.0833 - val_mean_absolute_percentage_error: 13.8312
# Epoch 371/400
#  - 0s - loss: 7.4776 - mean_squared_error: 7.4776 - mean_absolute_error: 2.1500 - mean_absolute_percentage_error: 6.5164 - val_loss: 30.0134 - val_mean_squared_error: 30.0134 - val_mean_absolute_error: 4.1187 - val_mean_absolute_percentage_error: 13.9276
# Epoch 372/400
#  - 0s - loss: 7.4724 - mean_squared_error: 7.4724 - mean_absolute_error: 2.1586 - mean_absolute_percentage_error: 6.5749 - val_loss: 30.2153 - val_mean_squared_error: 30.2153 - val_mean_absolute_error: 4.1519 - val_mean_absolute_percentage_error: 14.0786
# Epoch 373/400
#  - 0s - loss: 7.4877 - mean_squared_error: 7.4877 - mean_absolute_error: 2.1578 - mean_absolute_percentage_error: 6.5726 - val_loss: 29.4222 - val_mean_squared_error: 29.4222 - val_mean_absolute_error: 4.0905 - val_mean_absolute_percentage_error: 13.7959
# Epoch 374/400
#  - 0s - loss: 7.6918 - mean_squared_error: 7.6918 - mean_absolute_error: 2.1574 - mean_absolute_percentage_error: 6.4622 - val_loss: 29.4457 - val_mean_squared_error: 29.4457 - val_mean_absolute_error: 4.0750 - val_mean_absolute_percentage_error: 13.6943
# Epoch 375/400
#  - 0s - loss: 7.4370 - mean_squared_error: 7.4370 - mean_absolute_error: 2.1460 - mean_absolute_percentage_error: 6.5220 - val_loss: 29.2881 - val_mean_squared_error: 29.2881 - val_mean_absolute_error: 4.0669 - val_mean_absolute_percentage_error: 13.6690
# Epoch 376/400
#  - 0s - loss: 8.0165 - mean_squared_error: 8.0165 - mean_absolute_error: 2.2011 - mean_absolute_percentage_error: 6.5413 - val_loss: 29.4438 - val_mean_squared_error: 29.4438 - val_mean_absolute_error: 4.0330 - val_mean_absolute_percentage_error: 13.3220
# Epoch 377/400
#  - 0s - loss: 7.5117 - mean_squared_error: 7.5117 - mean_absolute_error: 2.1509 - mean_absolute_percentage_error: 6.5201 - val_loss: 31.9695 - val_mean_squared_error: 31.9695 - val_mean_absolute_error: 4.2786 - val_mean_absolute_percentage_error: 14.4937
# Epoch 378/400
#  - 0s - loss: 7.6307 - mean_squared_error: 7.6307 - mean_absolute_error: 2.1880 - mean_absolute_percentage_error: 6.6742 - val_loss: 29.7413 - val_mean_squared_error: 29.7413 - val_mean_absolute_error: 4.0971 - val_mean_absolute_percentage_error: 13.8097
# Epoch 379/400
#  - 0s - loss: 7.4811 - mean_squared_error: 7.4811 - mean_absolute_error: 2.1473 - mean_absolute_percentage_error: 6.5330 - val_loss: 30.3044 - val_mean_squared_error: 30.3044 - val_mean_absolute_error: 4.1602 - val_mean_absolute_percentage_error: 14.1088
# Epoch 380/400
#  - 0s - loss: 7.4555 - mean_squared_error: 7.4555 - mean_absolute_error: 2.1510 - mean_absolute_percentage_error: 6.5382 - val_loss: 30.0759 - val_mean_squared_error: 30.0759 - val_mean_absolute_error: 4.1447 - val_mean_absolute_percentage_error: 14.0654
# Epoch 381/400
#  - 0s - loss: 7.4561 - mean_squared_error: 7.4561 - mean_absolute_error: 2.1539 - mean_absolute_percentage_error: 6.5841 - val_loss: 30.0489 - val_mean_squared_error: 30.0489 - val_mean_absolute_error: 4.1501 - val_mean_absolute_percentage_error: 14.2025
# Epoch 382/400
#  - 0s - loss: 7.5502 - mean_squared_error: 7.5502 - mean_absolute_error: 2.1656 - mean_absolute_percentage_error: 6.6498 - val_loss: 28.4169 - val_mean_squared_error: 28.4169 - val_mean_absolute_error: 3.9986 - val_mean_absolute_percentage_error: 13.4989
# Epoch 383/400
#  - 0s - loss: 7.6334 - mean_squared_error: 7.6334 - mean_absolute_error: 2.1560 - mean_absolute_percentage_error: 6.4507 - val_loss: 28.3496 - val_mean_squared_error: 28.3496 - val_mean_absolute_error: 3.9580 - val_mean_absolute_percentage_error: 13.1960
# Epoch 384/400
#  - 0s - loss: 7.5409 - mean_squared_error: 7.5409 - mean_absolute_error: 2.1568 - mean_absolute_percentage_error: 6.5261 - val_loss: 28.8778 - val_mean_squared_error: 28.8778 - val_mean_absolute_error: 4.0121 - val_mean_absolute_percentage_error: 13.4913
# Epoch 385/400
#  - 0s - loss: 7.6582 - mean_squared_error: 7.6582 - mean_absolute_error: 2.1667 - mean_absolute_percentage_error: 6.4906 - val_loss: 27.9114 - val_mean_squared_error: 27.9114 - val_mean_absolute_error: 3.9735 - val_mean_absolute_percentage_error: 13.4463
# Epoch 386/400
#  - 0s - loss: 7.7512 - mean_squared_error: 7.7512 - mean_absolute_error: 2.2012 - mean_absolute_percentage_error: 6.8051 - val_loss: 30.1314 - val_mean_squared_error: 30.1314 - val_mean_absolute_error: 4.1963 - val_mean_absolute_percentage_error: 14.5954
# Epoch 387/400
#  - 0s - loss: 7.6324 - mean_squared_error: 7.6324 - mean_absolute_error: 2.1750 - mean_absolute_percentage_error: 6.6401 - val_loss: 27.3155 - val_mean_squared_error: 27.3155 - val_mean_absolute_error: 3.9159 - val_mean_absolute_percentage_error: 13.0668
# Epoch 388/400
#  - 0s - loss: 7.7212 - mean_squared_error: 7.7212 - mean_absolute_error: 2.1744 - mean_absolute_percentage_error: 6.5442 - val_loss: 28.3499 - val_mean_squared_error: 28.3499 - val_mean_absolute_error: 3.9979 - val_mean_absolute_percentage_error: 13.4974
# Epoch 389/400
#  - 0s - loss: 7.5237 - mean_squared_error: 7.5237 - mean_absolute_error: 2.1344 - mean_absolute_percentage_error: 6.4580 - val_loss: 29.1749 - val_mean_squared_error: 29.1749 - val_mean_absolute_error: 4.0728 - val_mean_absolute_percentage_error: 13.8192
# Epoch 390/400
#  - 0s - loss: 7.6219 - mean_squared_error: 7.6219 - mean_absolute_error: 2.1545 - mean_absolute_percentage_error: 6.5206 - val_loss: 28.7857 - val_mean_squared_error: 28.7857 - val_mean_absolute_error: 4.0364 - val_mean_absolute_percentage_error: 13.6056
# Epoch 391/400
#  - 0s - loss: 7.6134 - mean_squared_error: 7.6134 - mean_absolute_error: 2.1731 - mean_absolute_percentage_error: 6.6392 - val_loss: 28.9680 - val_mean_squared_error: 28.9680 - val_mean_absolute_error: 4.0489 - val_mean_absolute_percentage_error: 13.6673
# Epoch 392/400
#  - 0s - loss: 7.8060 - mean_squared_error: 7.8060 - mean_absolute_error: 2.1603 - mean_absolute_percentage_error: 6.4746 - val_loss: 29.2797 - val_mean_squared_error: 29.2797 - val_mean_absolute_error: 4.0609 - val_mean_absolute_percentage_error: 13.6684
# Epoch 393/400
#  - 0s - loss: 7.4730 - mean_squared_error: 7.4730 - mean_absolute_error: 2.1574 - mean_absolute_percentage_error: 6.5666 - val_loss: 30.4094 - val_mean_squared_error: 30.4094 - val_mean_absolute_error: 4.1740 - val_mean_absolute_percentage_error: 14.2200
# Epoch 394/400
#  - 0s - loss: 7.8277 - mean_squared_error: 7.8277 - mean_absolute_error: 2.2076 - mean_absolute_percentage_error: 6.7728 - val_loss: 29.4605 - val_mean_squared_error: 29.4605 - val_mean_absolute_error: 4.0785 - val_mean_absolute_percentage_error: 13.8041
# Epoch 395/400
#  - 0s - loss: 7.4764 - mean_squared_error: 7.4764 - mean_absolute_error: 2.1349 - mean_absolute_percentage_error: 6.4325 - val_loss: 28.1186 - val_mean_squared_error: 28.1186 - val_mean_absolute_error: 3.9620 - val_mean_absolute_percentage_error: 13.2657
# Epoch 396/400
#  - 0s - loss: 7.5977 - mean_squared_error: 7.5977 - mean_absolute_error: 2.1522 - mean_absolute_percentage_error: 6.4682 - val_loss: 28.7639 - val_mean_squared_error: 28.7639 - val_mean_absolute_error: 4.0410 - val_mean_absolute_percentage_error: 13.7138
# Epoch 397/400
#  - 0s - loss: 7.3621 - mean_squared_error: 7.3621 - mean_absolute_error: 2.1274 - mean_absolute_percentage_error: 6.4656 - val_loss: 27.9224 - val_mean_squared_error: 27.9224 - val_mean_absolute_error: 3.9894 - val_mean_absolute_percentage_error: 13.5162
# Epoch 398/400
#  - 0s - loss: 7.5415 - mean_squared_error: 7.5415 - mean_absolute_error: 2.1521 - mean_absolute_percentage_error: 6.5375 - val_loss: 28.0660 - val_mean_squared_error: 28.0660 - val_mean_absolute_error: 3.9838 - val_mean_absolute_percentage_error: 13.4401
# Epoch 399/400
#  - 0s - loss: 8.2928 - mean_squared_error: 8.2928 - mean_absolute_error: 2.2483 - mean_absolute_percentage_error: 6.6463 - val_loss: 29.3767 - val_mean_squared_error: 29.3767 - val_mean_absolute_error: 4.0589 - val_mean_absolute_percentage_error: 13.5432
# Epoch 400/400
#  - 0s - loss: 7.6514 - mean_squared_error: 7.6514 - mean_absolute_error: 2.1813 - mean_absolute_percentage_error: 6.6891 - val_loss: 32.8335 - val_mean_squared_error: 32.8335 - val_mean_absolute_error: 4.3961 - val_mean_absolute_percentage_error: 14.9882

# %%
# Listado de métricas almacenadas durante el entrenamiento
print(history.history.keys())
# Out:
# dict_keys(['val_loss', 'val_mean_squared_error', 'val_mean_absolute_error', 'val_mean_absolute_percentage_error', 'loss', 'mean_squared_error', 'mean_absolute_error', 'mean_absolute_percentage_error'])

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharex=False, sharey=False, figsize=(15,15))


# Resumen de 'mean_squared_error'
ax1.plot(history.history['mean_squared_error'])
ax1.plot(history.history['val_mean_squared_error'])
ax1.set_title('Precision del Modelo')
ax1.set_ylabel('MSE')
ax1.set_xlabel('epoch')
ax1.legend(['train', 'test'], loc='upper left')
#plt.show()

# Resumen de 'mean_absolute_error'
ax2.plot(history.history['mean_absolute_error'])
ax2.plot(history.history['val_mean_absolute_error'])
ax2.set_title('Precision del Modelo')
ax2.set_ylabel('MAE')
ax2.set_xlabel('epoch')
ax2.legend(['train', 'test'], loc='upper left')
#plt.show()

# Resumen de 'mean_absolute_percentage_error'
ax3.plot(history.history['mean_absolute_percentage_error'])
ax3.plot(history.history['val_mean_absolute_percentage_error'])
ax3.set_title('Precision del Modelo')
ax3.set_ylabel('MAPE')
ax3.set_xlabel('epoch')
ax3.legend(['train', 'test'], loc='upper left')
#plt.show()

# Resumen de la funcion de perdida definida
ax4.plot(history.history['loss'])
ax4.plot(history.history['val_loss'])
ax4.set_title('Perdidas del modelo')
ax4.set_ylabel('Perdidas')
ax4.set_xlabel('epoch')
ax4.legend(['train', 'test'], loc='upper left')
fig.tight_layout()

plt.show()

# %% [markdown]
# ### Predicción

# %%
# make a prediction
Y_pred = model.predict(X_test_rs)

# show the inputs and predicted outputs
for i in range(len(X_test_rs)):
        print("X=%s, Predicted=%s" % (X_test_rs[i], Y_pred[i]))

# %%
#Creamos el dataframe de validación
test_val = pd.DataFrame(X_test)
test_val.columns = (["pwr","porc","viento_aparente"])
test_val["spd"] = Y_test
test_val["Y_pred"] = Y_pred
test_val["diff"] = test_val["spd"]-test_val["Y_pred"]
test_val.head()

# %%
#Ploteamos las diferencias entre las velocidades reales y las predichas por el modelo
plt.hist(test_val['diff'])

# %%
#Mostramos los valores significativos de las predicciones y la diferencia con los reales

print("Predicciones:")
print(test_val["Y_pred"].mean())
print(test_val["Y_pred"].max())
print(test_val["Y_pred"].min())

print("Diferencias:")
print(test_val["diff"].mean())
print(test_val["diff"].max())
print(test_val["diff"].min())

# %% [markdown]
# #### Comprobaciones finales del resultado

# %%
test_val['dist'] = df_test['dist']
test_val['time_seg'] = df_test['time_seg']
test_val['time_seg_pred'] = test_val['dist']/(test_val['Y_pred']/3.6)

# %%
tiempo_real = test_val['time_seg'].sum()
tiempo_pred = test_val['time_seg_pred'].sum()
print('Tiempo Real: %s' %str(datetime.timedelta(seconds=int(tiempo_real))))
print('Tiempo Predicho: %s' %str(datetime.timedelta(seconds=tiempo_pred)))

# %% [markdown]
# #### Mostramos los datos con mayor diferencia para analizar

# %%
test_val[(test_val["diff"]>8) | (test_val["diff"]<-10)]

# %% [markdown]
# ### Exportamos el Modelo para ser usado en el Simulador

# %%
pickle.dump(scalarX, open("Scaler.model", 'wb'))


model.save("TF_Tramos_2.model")
#Para cargar el modelo
#https://keras.io/getting-started/faq/#how-can-i-save-a-keras-model
