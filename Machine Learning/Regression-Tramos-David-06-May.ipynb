# %%
#La Potencia viene dada por la siguiente formula

# %% [markdown]
# $P = \frac{\rho}{2}(V+wV)^2VCdA+(Cr+\%)mgV$
#
# Dónde:
#
# P es la potencia necesaria
#
# $\rho$ es la densidad del aire
#
# V es la velocidad
#
# wV es velocidad el viento
#
# Cd es el coeficiente de drag
#
# A es el área efectiva
#
# Cr es el coeficiente de rozamiento
#
# $\%$ es la pendiente
#
# m es la masa total del conjunto bicicleta - ciclista

# %%
import os
import pandas as pd
import matplotlib.pylab as plt
# %matplotlib inline
plt.style.use('seaborn')
import numpy as np

# %% [markdown]
# ### Cargamos los datos

# %%
#path = '../Entrenamientos/result_tramos.xlsx'
path = '../Entrenamientos/Procesado_Tramos.xlsx'

# %%
df = pd.read_excel(path)

# %%
df.describe()
# Out:
#             tramo  tramo_inicial  tramo_final         pwr     time_seg  \
# count  283.000000     283.000000   283.000000  283.000000   283.000000
# mean    50.038869    3626.088339  3695.734982  166.896851   138.798587
# std     33.047386    2359.016002  2353.448358   75.436162   294.498658
# min      0.000000       0.000000    12.000000    0.000000     1.000000
# 25%     23.000000    1523.000000  1603.000000  105.409955    20.000000
# 50%     47.000000    3523.000000  3526.000000  171.142659    56.000000
# 75%     70.000000    5937.500000  6115.000000  221.707288   125.000000
# max    129.000000    7729.000000  7796.000000  648.000000  2761.000000
#
#                dist         spd  viento_aparente        porc
# count    283.000000  283.000000       283.000000  283.000000
# mean     959.941520   30.333649             -inf         inf
# std     1563.664211    9.299367              NaN         NaN
# min        0.000000    0.000000             -inf   -6.677410
# 25%      121.776438   24.367954        -8.386325   -1.070971
# 50%      468.799905   29.952505        -2.166430   -0.007052
# 75%      905.673921   36.336244         7.279960    1.200993
# max    10273.070042   64.800000        26.699485         inf

# %%
df = df[df["viento_aparente"]!=-np.inf]

# %%
df.describe()
# Out:
#             tramo  tramo_inicial  tramo_final         pwr     time_seg  \
# count  282.000000     282.000000   282.000000  282.000000   282.000000
# mean    50.078014    3617.893617  3687.783688  166.678684   139.280142
# std     33.099563    2359.171158  2353.821173   75.480779   294.910571
# min      0.000000       0.000000    12.000000    0.000000     1.000000
# 25%     23.000000    1522.500000  1596.500000  105.383618    20.250000
# 50%     47.000000    3514.500000  3525.500000  171.140529    56.500000
# 75%     70.000000    5937.250000  6124.000000  221.205250   125.000000
# max    129.000000    7729.000000  7796.000000  648.000000  2761.000000
#
#                dist         spd  viento_aparente        porc
# count    282.000000  282.000000       282.000000  282.000000
# mean     963.345568   30.441215        -0.200655   -0.033003
# std     1565.393258    9.137827        11.146978    2.166262
# min        9.079168    0.770052       -21.641147   -6.677410
# 25%      129.987954   24.412312        -8.369160   -1.072187
# 50%      469.955006   29.964252        -1.899402   -0.013285
# 75%      906.990831   36.381969         7.301920    1.194253
# max    10273.070042   64.800000        26.699485    7.137195

# %%
df.head()
# Out:
#    tramo  tramo_inicial  tramo_final         pwr  time_seg         dist  \
# 0      0              0           65   77.836186       106   966.000000
# 1      1             65          432  255.381555       980  4819.000000
# 2      2            432          468  152.194252        44   473.935824
# 3      3            468          532  248.770434       120   813.223602
# 4      4            532          548  155.753257        21   206.720563
#
#          spd  viento_aparente      porc                        prueba
# 0  32.807547         6.718880 -3.377386  20180406_LEVS_195_90_R_E.gpx
# 1  17.702449         7.188764  4.181100  20180406_LEVS_195_90_R_E.gpx
# 2  38.776567         8.537489 -1.737873  20180406_LEVS_195_90_R_E.gpx
# 3  24.396708         8.334437  2.662585  20180406_LEVS_195_90_R_E.gpx
# 4  35.437811         8.287183 -0.873144  20180406_LEVS_195_90_R_E.gpx

# %%
# Hacemos que la target sea el pwr solo por ver como funciona el modelo. Luego habrá que despejar y calcular spd

# %%
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
df_lm = df[['pwr','spd','porc','viento_aparente']]

# %% [raw]
# train = round(len(df_lm)*0.7)
# train
# test = len(df_lm)-train
# test

# %% [raw]
# X_train = df_lm_x[:train]
# X_test = df_lm_x[test:]

# %% [raw]
# Y_train = df_lm_y[:train]
# Y_test = df_lm_y[test:]

# %%
df_lm_x = df[['spd','porc','viento_aparente']]
df_lm_y = df[['pwr']]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(df_lm_x, df_lm_y, test_size=0.30, random_state=42)

# %% [markdown]
# ### Probamos con Ensemble

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn import tree
from sklearn.model_selection import cross_val_score

# %%
rf = RandomForestRegressor(max_features=2, min_samples_split=4, n_estimators=50, min_samples_leaf=2)
gb = GradientBoostingRegressor(loss='quantile', learning_rate=0.0001, n_estimators=50, max_features='log2', min_samples_split=2, max_depth=1)
ada_tree_backing = tree.DecisionTreeRegressor(max_features='sqrt', splitter='random', min_samples_split=4, max_depth=3)
ab = AdaBoostRegressor(ada_tree_backing, learning_rate=0.1, loss='square', n_estimators=1000)

# %%
rf.fit(X_train, Y_train)
Y_pred = rf.predict(X_test)
plt.scatter(Y_test, Y_pred)
plt.plot( [0,250],[0,250], c="red" )
# Out:
# C:\Users\eduardo.hernanz\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.

# %%
metrics.explained_variance_score(Y_test, Y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-57e9d11cde59> in <module>()
# ----> 1 metrics.explained_variance_score(Y_test, Y_pred)
#
# NameError: name 'metrics' is not defined

# %%
gb.fit(X_train, Y_train)
Y_pred = gb.predict(X_test)
plt.scatter(Y_test, Y_pred)
plt.plot( [0,250],[0,250], c="red" )
# Out:
# C:\Users\eduardo.hernanz\AppData\Local\Continuum\Anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
metrics.explained_variance_score(Y_test, Y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-57e9d11cde59> in <module>()
# ----> 1 metrics.explained_variance_score(Y_test, Y_pred)
#
# NameError: name 'metrics' is not defined

# %%
ab.fit(X_train, Y_train)
Y_pred = ab.predict(X_test)
plt.scatter(Y_test, Y_pred)
plt.plot( [0,250],[0,250], c="red" )
# Out:
# C:\Users\eduardo.hernanz\AppData\Local\Continuum\Anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
metrics.explained_variance_score(Y_test, Y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-57e9d11cde59> in <module>()
# ----> 1 metrics.explained_variance_score(Y_test, Y_pred)
#
# NameError: name 'metrics' is not defined

# %%
#Grid Search con RFR

# %%
from sklearn.model_selection import GridSearchCV
#max_features=2, min_samples_split=4, n_estimators=50, min_samples_leaf=2
rfr = RandomForestRegressor(n_jobs=1, random_state=0, max_features=2)
param_grid = {'n_estimators': [1000]}
# 'n_estimators': [1000], 'max_features': [10,15,20,25], 'max_depth':[20,20,25,25,]}
model = GridSearchCV(estimator=rfr, param_grid=param_grid, n_jobs=1, cv=10)

model.fit(X=X_train, y=Y_train)
print('Random forecast regression...')
print('Best Params:')
print(model.best_params_)
print('Best CV Score:')
print(-model.best_score_)

Y_pred = model.predict(X_test)

# %%
plt.scatter(Y_test, Y_pred)
plt.plot( [0,250],[0,250], c="red" )

# %%
metrics.explained_variance_score(Y_test, Y_pred)

# %%
# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# Make predictions using the testing set
Y_pred = regr.predict(X_test)

# %%
X_test.describe()
# Out:
#              spd       porc  viento_aparente
# count  85.000000  85.000000        85.000000
# mean   29.774977  -0.043758         0.394085
# std     8.786220   2.346467        11.293419
# min     2.375887  -6.677410       -20.548437
# 25%    22.573802  -1.186859        -8.327634
# 50%    29.952505  -0.040300        -0.765053
# 75%    36.073203   1.345029         7.078932
# max    47.536057   5.452840        25.437736

# %%
Y_test.describe()
# Out:
#               pwr
# count   85.000000
# mean   163.669075
# std     75.197283
# min     13.116462
# 25%     97.603894
# 50%    175.690544
# 75%    223.351979
# max    377.761160

# %%
plt.scatter(Y_test, Y_pred)
plt.plot( [0,250],[0,250], c="red" )

# %%
# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(Y_test, Y_pred))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(Y_test, Y_pred))

# Plot outputs
plt.subplot(131)
plt.scatter(X_test['spd'], Y_test,  color='black')
plt.plot(X_test['spd'], Y_pred, color='blue', linewidth=3)
plt.grid(True)

plt.subplot(132)
plt.scatter(X_test['porc'], Y_test,  color='black')
plt.plot(X_test['porc'], Y_pred, color='red', linewidth=3)
plt.grid(True)

plt.subplot(133)
plt.scatter(X_test['viento_aparente'], Y_test,  color='black')
plt.plot(X_test['viento_aparente'], Y_pred, color='green', linewidth=3)
plt.grid(True)

#plt.xticks(())
#plt.yticks(())

plt.show()
# Out:
# Coefficients:
#  [[  4.77035466  34.99324817  -0.40537567]]
# Mean squared error: 1902.00
# Variance score: 0.66

# %%
#Probamos otra cosa. Vamos a darle al modelo calculados los terminos de la formula

# %% [markdown]
# $P = \frac{\rho}{2}(V+wV)^2VCdA+(Cr+\%)mgV$
#
# $P = \frac{\rho}{2}(V+wV)^2VCdA+CrmgV+\%mgV$

# %%
#añadimos aqui
#df_lm_x = df[['spd','porc','viento_aparente']]
#df_lm_y = df[['pwr']]

df_lm_x['termino_cda'] = (df_lm_x['spd']+df_lm_x['viento_aparente'])**2*df_lm_x['spd']
df_lm_x['termino_roz'] = df_lm_x['spd']*90
df_lm_x['termino_cte'] = df_lm_x['spd']*df_lm_x['porc']*90
# Out:
# C:\Users\eduardo.hernanz\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\eduardo.hernanz\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\eduardo.hernanz\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
df_lm_x
# Out:
#           spd      porc  viento_aparente    termino_cda  termino_roz  \
# 0   32.807547 -3.377386         6.718880   51256.492412  2952.679245
# 1   17.702449  4.181100         7.188764   10967.950311  1593.220408
# 2   38.776567 -1.737873         8.537489   86805.995229  3489.891065
# 3   24.396708  2.662585         8.334437   26136.872836  2195.703725
# 4   35.437811 -0.873144         8.287183   67752.668023  3189.402973
# 5   26.917836  1.566720         8.076853   32964.340940  2422.605198
# 6   36.101408 -1.730661         8.562138   72016.258518  3249.126761
# 7   22.792053  2.126107         7.106878   20374.865937  2051.284768
# 8   32.620000 -1.471857         7.323881   52045.654463  2935.800000
# 9   27.138462  0.946517         5.706683   29277.067899  2442.461538
# 10  29.639098 -2.440001         3.616604   32779.114815  2667.518797
# 76  25.878261 -1.076144         3.569760   22441.264253  2329.043478
#
#      termino_cte
# 0   -9972.338295
# 1    6661.413079
# 2   -6064.986292
# 3    5846.247560
# 4   -2784.809017
# 5    3795.544367
# 6   -5623.138156
# 7    4361.250254
# 8   -4321.076598
# 9    2311.831178
# 10  -6508.748888
# 11   2484.572208
# 12   -191.414024
# 13     41.967983
# 14   -615.319237
# 15   4471.239652
# 16  -3723.699076
# 17   2259.894767
# 18   -507.505454
# 19   5902.914310
# 20  -1274.692372
# 21   7793.320282
# 22 -28567.595098
# 23   6444.386801
# 24  -3232.147218
# 25   2000.227006
# 26   -122.703145
# 27     49.930413
# 28   -112.416839
# 29    183.163888
# ..           ...
# 47    289.138287
# 48   -200.684206
# 49   2366.570478
# 50  -1849.039080
# 51   5246.256258
# 52 -13846.575272
# 53   5844.051217
# 54  -1290.137081
# 55   2586.346604
# 56  -6982.503332
# 57    296.140204
# 58 -14554.030270
# 59    477.684419
# 60  -9071.691500
# 61   6796.072752
# 62  -9533.953475
# 63    303.215544
# 64 -17124.434822
# 65   4901.306388
# 66 -12150.917705
# 67    875.154605
# 68  -8506.174855
# 69   2190.105711
# 70  -6201.632480
# 71    116.083486
# 72  -2311.966388
# 73   1135.923658
# 74   -582.071854
# 75   2567.946687
# 76  -2506.386086
#
# [282 rows x 6 columns]

# %%
df_lm_x.describe()
# Out:
#               spd        porc  viento_aparente    termino_cda  termino_roz  \
# count  282.000000  282.000000       282.000000     282.000000   282.000000
# mean    30.441215   -0.033003        -0.200655   39109.305471  2739.709366
# std      9.137827    2.166262        11.146978   43842.794260   822.404425
# min      0.770052   -6.677410       -21.641147       1.267319    69.304707
# 25%     24.412312   -1.072187        -8.369160   10840.445342  2197.108118
# 50%     29.964252   -0.013285        -1.899402   22785.412497  2696.782684
# 75%     36.381969    1.194253         7.301920   51452.090118  3274.377190
# max     64.800000    7.137195        26.699485  310902.126004  5832.000000
#
#         termino_cte
# count    282.000000
# mean   -1349.873547
# std     6346.142209
# min   -28567.595098
# 25%    -3124.752890
# 50%      -14.528036
# 75%     2605.206284
# max     7793.320282

# %%
df_lm_x2 = df_lm_x[['termino_cda','termino_roz','termino_cte']]
df_lm_y2 = df_lm_y[['pwr']]

# %% [raw]
# X_train2 = df_lm_x2[:train]
# X_test2 = df_lm_x2[test:]

# %% [raw]
# Y_train2 = df_lm_y2[:train]
# Y_test2 = df_lm_y2[test:]

# %%
X_train2, X_test2, Y_train2, Y_test2 = train_test_split(df_lm_x2, df_lm_y2, test_size=0.30, random_state=42)

# %%
# Create linear regression object
regr2 = linear_model.LinearRegression()

# Train the model using the training sets
regr2.fit(X_train2, Y_train2)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# Make predictions using the testing set
Y_pred2 = regr2.predict(X_test2)

# %%
# The coefficients
print('Coefficients: \n', regr2.coef_)
# The mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(Y_test2, Y_pred2))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(Y_test2, Y_pred2))
# Out:
# Coefficients:
#  [[ 0.00034094  0.03369161  0.01110718]]
# Mean squared error: 2780.67
# Variance score: 0.50

# %%
plt.scatter(Y_test2, Y_pred2)
plt.plot( [0,250],[0,250], c="red" )

# %% [markdown]
# ### Ridge

# %%
rid = linear_model.Ridge(alpha=0.5)

# %%
rid.fit(X_train2,Y_train2)
# Out:
# Ridge(alpha=0.5, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
Y_predict_rid = rid.predict(X_test2)

# %%
# The coefficients
print('Coefficients: \n', rid.coef_)
# The mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(Y_test2, Y_predict_rid))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(Y_test2, Y_predict_rid))
# Out:
# Coefficients:
#  [[ 0.00034094  0.03369161  0.01110718]]
# Mean squared error: 2780.67
# Variance score: 0.50

# %%
rid2 = linear_model.RidgeCV(alphas=[0.1, 1.0, 10.0])

# %%
rid2.fit(X_train2,Y_train2)
# Out:
# RidgeCV(alphas=[0.1, 1.0, 10.0], cv=None, fit_intercept=True, gcv_mode=None,
#     normalize=False, scoring=None, store_cv_values=False)

# %%
Y_predict_rid2 = rid.predict(X_test2)

# %%
# The coefficients
print('Coefficients: \n', rid2.coef_)
# The mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(Y_test2, Y_predict_rid2))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(Y_test2, Y_predict_rid2))
# Out:
# Coefficients:
#  [[ 0.00034094  0.0336916   0.01110718]]
# Mean squared error: 2780.67
# Variance score: 0.50

# %%
plt.scatter(Y_test2, Y_predict_rid2)
plt.plot( [0,250],[0,250], c="red" )

# %%
['pwr','spd','porc','viento_aparente']
# Out:
# ['pwr', 'spd', 'porc', 'viento_aparente']

# %% [markdown]
# ### Filtramos potencias >100w y <350w

# %%
df_lm2 = df.loc[(df['pwr']>100)&(df['pwr']<350)]

# %%
df_lm2
# Out:
#     tramo  tramo_inicial  tramo_final         pwr  time_seg         dist  \
# 1       1             65          432  255.381555       980  4819.000000
# 2       2            432          468  152.194252        44   473.935824
# 3       3            468          532  248.770434       120   813.223602
# 4       4            532          548  155.753257        21   206.720563
# 5       5            548          636  217.073745       170  1271.120011
# 7       7            688          892  219.577239       453  2868.000000
# 9       9            985         1024  202.978559        78   588.000000
# 11     11           1095         1126  168.365547        74   437.000000
# 15     15           1148         1206  201.860105       140   703.000000
# 16     16           1206         1252  102.681604        87   768.000000
# 17     17           1252         1290  211.367571        78   578.000000
# 18     18           1290         1305  149.557451        29   266.000000
# 19     19           1305         2003  239.162193      1618  9191.000000
# 20     20           2003         2017  126.563497        28   244.000000
# 21     21           2017         2813  243.804600      2761  9305.000000
# 23     23           3401         3457  200.490629       144   704.236046
# 25     25           3489         3523  131.522378        78   445.200064
# 26     26           3523         3524  239.409741         2    14.100059
# 27     27           3524         3525  187.857245         2    16.349989
# 28     28           3525         3526  202.329971         2    11.292927
# 31     31           3587         3899  221.551433      1220  3795.770186
# 33     33           4193         4220  234.693054        60   371.950118
# 34     34           4220         4694  165.878163       498  6130.712969
# 35     35           4694         5390  215.339885      2575  8252.417053
# 40     40           5938         6097  115.383830       240  2182.000000
# 41     41           6097         6133  199.839826        69   468.799905
# 42     42           6133         6179  163.669016        94   734.908361
# 43     43           6179         6195  126.006619        35   200.602273
# 45     45           6328         6347  203.078360        38   240.722611
# 46     46           6347         6369  107.394053        44   323.277389
# ..    ...            ...          ...         ...       ...          ...
# 42     42           2359         2546  127.475646       205  2431.000000
# 43     43           2546         2827  255.865999       717  3625.000000
# 73  28.414286        -2.461087  0.444191  20180422_LEVS_195_90_R_E.gpx
# 75  26.432877         0.808750  1.079441  20180422_LEVS_195_90_R_E.gpx
#
# [219 rows x 10 columns]

# %%
#añadimos aqui
df_lm_x2 = df_lm2[['spd','porc','viento_aparente']]
df_lm_y2 = df_lm2[['pwr']]

df_lm_x2['termino_cda'] = (df_lm2['spd']+df_lm2['viento_aparente'])**2*df_lm2['spd']
df_lm_x2['termino_roz'] = df_lm2['spd']*90
df_lm_x2['termino_cte'] = df_lm2['spd']*df_lm2['porc']*90
# Out:
# C:\Users\eduardo.hernanz\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\eduardo.hernanz\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\eduardo.hernanz\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
df_lm_x2
# Out:
#           spd      porc  viento_aparente    termino_cda  termino_roz  \
# 1   17.702449  4.181100         7.188764   10967.950311  1593.220408
# 2   38.776567 -1.737873         8.537489   86805.995229  3489.891065
# 3   24.396708  2.662585         8.334437   26136.872836  2195.703725
# 4   35.437811 -0.873144         8.287183   67752.668023  3189.402973
# 5   26.917836  1.566720         8.076853   32964.340940  2422.605198
# 7   22.792053  2.126107         7.106878   20374.865937  2051.284768
# 9   27.138462  0.946517         5.706683   29277.067899  2442.461538
# 11  21.259459  1.298545         6.385003   16246.826002  1913.351351
# 15  18.077143  2.748246        -0.765053    5417.872298  1626.942857
# 16  31.779310 -1.301930         8.441623   51410.135682  2860.137931
# 17  26.676923  0.941261         7.539226   31231.869614  2400.923077
# 18  33.020690 -0.170770         8.494773   56912.268054  2971.862069
# 19  20.449691  3.207283         5.941845   14243.478659  1840.472188
# 20  31.371429 -0.451470         7.236038   46760.259688  2823.428571
# 21  12.132561  7.137195         2.502077    2598.462299  1091.930460
# 23  17.605901  4.067062         5.810498    9653.804551  1584.531104
# 25  20.547695  1.081617         3.601939   11983.515658  1849.292574
# 26  25.380106 -0.053718         2.334200   19494.022614  2284.209571
# 27  29.429980  0.018851         1.086342   27406.549054  2648.698205
# 28  20.327268 -0.061448         1.399477    9595.516617  1829.454124
# 31  11.200633  5.870399         5.547823    3141.898584  1008.057000
# 33  22.317007  2.290759        -0.591674   10533.406747  2008.530639
# 34  44.318407 -2.914999        -1.527323   81150.411879  3988.656630
# 35  11.537360  6.468743         5.382537    3302.948729  1038.362379
# 40  32.730000 -1.657458        -7.835965   20283.206230  2945.700000
# 41  24.459126  1.799504        -7.931274    6681.496290  2201.321295
# 42  28.145427 -0.593717        -7.087620   12480.560838  2533.088394
# 43  20.633377  0.547677        -7.465046    3577.929382  1857.003899
# 45  22.805300  0.610510        -8.403216    4730.276015  2052.476998
# 46  26.449968 -0.814198        -8.369434    8646.645691  2380.497138
# ..        ...       ...              ...            ...          ...
# 42  42.690732 -3.191646         7.078932  105745.770460  3842.165854
# 43  18.200837  4.056833         7.572948   12090.597249  1638.075314
# 44  23.400000 -0.034936        11.032035   27742.221283  2106.000000
# 45  21.600000  0.039680        10.053286   21641.698627  1944.000000
# 47  28.800000  0.111550         9.929257   43198.713581  2592.000000
# 48  30.000000 -0.074327        10.130495   48313.698943  2700.000000
# 49  30.600000  0.859321         9.505251   49217.992210  2754.000000
# 25%     23.686989   -0.601474        -8.386325   10216.041635  2131.829026
# 50%     29.712799    0.114959        -1.632373   20642.945645  2674.151873
# 75%     35.268905    1.619251         7.556087   48780.450111  3174.201487
# max     52.740449    7.137195        26.699485  205578.710551  4746.640448
#
#         termino_cte
# count    219.000000
# mean      76.782296
# std     5090.272188
# min   -20338.717143
# 25%    -1815.001786
# 50%      296.140204
# 75%     3765.190072
# max     7793.320282

# %%
df_lm_y2.describe()
# Out:
#               pwr
# count  219.000000
# mean   191.522134
# std     49.502506
# min    100.998157
# 25%    155.187883
# 50%    194.453542
# 75%    234.449697
# max    338.535682

# %%
df_lm_x3 = df_lm_x2[['termino_cda','termino_roz','termino_cte']]
df_lm_y3 = df_lm_y2[['pwr']]

# %%
plt.hist(df_lm_y3['pwr'])
plt.show()

# %%
len(df_lm_x3)==len(df_lm_y3)
# Out:
# True

# %%
X_train3, X_test3, Y_train3, Y_test3 = train_test_split(df_lm_x3, df_lm_y3, test_size=0.30, random_state=42)

# %% [raw]
# train2 = round(len(df_lm_x3)*0.7)
# train2
# test2 = len(df_lm_x3)-train2
# test2

# %% [raw]
# X_train3 = df_lm_x3[:train2]
# X_test3 = df_lm_x3[test2:]

# %% [raw]
# Y_train3 = df_lm_y3[:train2]
# Y_test3 = df_lm_y3[test2:]

# %%
# Create linear regression object
regr3 = linear_model.LinearRegression()

# Train the model using the training sets
regr3.fit(X_train3, Y_train3)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# Make predictions using the testing set
Y_pred3 = regr3.predict(X_test3)

# %%
# The coefficients
print('Coefficients: \n', regr3.coef_)
# The mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(Y_test3, Y_pred3))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(Y_test3, Y_pred3))
# Out:
# Coefficients:
#  [[ -1.80906209e-05   2.14266136e-02   8.19724202e-03]]
# Mean squared error: 1636.32
# Variance score: 0.37

# %%
X_train3
# Out:
#        termino_cda  termino_roz   termino_cte
# 13    22969.701640  2190.527954   5363.670183
# 19     3036.525389  2663.205073   4353.677680
# 85    48992.020101  2096.941046   5632.154671
# 37     2940.366802  1765.117517   5357.477114
# 28    14787.736702  2862.000000   -265.228064
# 48    14281.937296  2670.027687  -3584.776400
# 19    14243.478659  1840.472188   5902.914310
# 52    19564.195379  2935.039749  -3344.603487
# 45     4730.276015  2052.476998   1253.058350
# 61     4425.184437  2031.642160   3892.797141
# 45      876.536142  1885.822946   5156.820600
# 5      7908.713697  2030.926829   5184.226630
# 54    63330.762487  3088.800000  -1290.137081
# 74    20079.904438  2988.795377  -1887.662407
# 115   75485.402387  3308.049542   4801.265072
# 27     9084.664797  2511.000000     86.332791
# 31     1225.717145  2207.088055   2869.689667
# 60    19287.771674  2931.454625  -2508.725007
# 26     5534.711729  2268.000000   -164.205149
# 33    12189.444889  2137.678126   3956.467701
# 14    36724.991572  2688.848588  -1960.920264
# 42    12480.560838  2533.088394  -1503.937109
# 126    8907.185797  2849.479810  -5178.590468
# 89    13160.550884  1265.637927   6901.320621
# 105   21553.236787  2589.868726   5171.735935
# 3     26136.872836  2195.703725   5846.247560
# 32    33993.887038  3562.588824  -6594.070242
# 67    10568.627652  2427.423414   1412.961407
# 111    9264.641225  2479.909300   7431.418311
# 92    59609.732107  3660.826721  -8416.217765
# ..             ...          ...           ...
# 6     33934.824568  3479.878954  -6999.295676
# 11    33509.707549  2669.553191   3584.420425
# 66    58191.236955  3956.975214 -12150.917705
# 40   205578.710551  4746.640448 -20338.717143
# 44    27742.221283  2106.000000    -73.574182
# 107   24924.635361  2534.710914   3040.652224
# 55    25424.430809  3094.189153    355.705838
# 7     21341.229619  2500.732394   2321.901127
# 60   117205.875040  4152.806502  -9071.691500
# 2     86805.995229  3489.891065  -6064.986292
# 75     1604.779679  1464.290974   3977.145074
# 129       6.045873  1883.096970   3118.516659
# 108   75336.489988  3438.833447  -7881.391921
# 1     18575.059544  2125.979926   5341.610995
# 75   130725.994275  3617.460166   1283.780687
# 70   103738.481510  2975.488207  -1794.866544
# 91    56178.015282  2909.187618    711.859173
# 49     2907.027336  1691.344688   6302.517424
# 56    76007.414945  3262.031585  -6982.503332
# 29     3581.058078  1968.020865   3162.985083
# 97     2128.219250  2351.287332   3835.682466
# 75    19616.003048  2378.958904   2567.946687
# 31     3141.898584  1008.057000   5917.696341
# 41    45694.302045  2665.433790   6168.162415
# 25     6649.177741  3118.924246   1436.618557
# 78   170957.443919  3757.591685  -4033.412663
# 21     2598.462299  1091.930460   7793.320282
# 58    31299.170720  2025.205766  -1049.989162
# 30    45705.422029  3698.619718  -9969.333694
# 73    90806.132640  2887.240897   5336.049298
#
# [153 rows x 3 columns]

# %%
df_lm_x2.describe()
# Out:
#               spd        porc  viento_aparente    termino_cda  termino_roz  \
# count  219.000000  219.000000       219.000000     219.000000   219.000000
# mean    29.735805    0.455457        -0.229732   35905.694693  2676.222446
# std      8.507774    1.961889        10.989647   38676.971591   765.699695
# min      0.770052   -4.284866       -21.641147       6.045873    69.304707
# 25%     23.686989   -0.601474        -8.386325   10216.041635  2131.829026
# 50%     29.712799    0.114959        -1.632373   20642.945645  2674.151873
# 75%     35.268905    1.619251         7.556087   48780.450111  3174.201487
# max     52.740449    7.137195        26.699485  205578.710551  4746.640448
#
#         termino_cte
# count    219.000000
# mean      76.782296
# std     5090.272188
# min   -20338.717143
# 25%    -1815.001786
# 50%      296.140204
# 75%     3765.190072
# max     7793.320282

# %%
len(Y_pred3)
# Out:
# 66

# %%
results = pd.DataFrame(X_test3)

# %%
 results['Y_test'] = Y_test3

# %%
 results['Y_pred'] = Y_pred3

# %%
results['dif'] = results['Y_test']-results['Y_pred']

# %%
plt.hist(results['dif'])
# Out:
# (array([  2.,   8.,   8.,   8.,  13.,  11.,   8.,   6.,   1.,   1.]),
#  array([-97.19684389, -78.11179197, -59.02674005, -39.94168812,
#         -20.8566362 ,  -1.77158428,  17.31346764,  36.39851956,
#          55.48357149,  74.56862341,  93.65367533]),
#  <a list of 10 Patch objects>)

# %%
plt.scatter(Y_test3, Y_pred3)
plt.plot( [0,250],[0,250], c="red" )

# %%
from sklearn import metrics

# %%
metrics.explained_variance_score(Y_test3, Y_pred3)
# Out:
# 0.42076371334712903
