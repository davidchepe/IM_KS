# %%
#La Potencia viene dada por la siguiente formula

# %% [markdown]
# $P = \frac{\rho}{2}(V+wV)^2VCdA+(Cr+\%)mgV$
#
# Dónde:
#
# P es la potencia necesaria
#
# $\rho$ es la densidad del aire
#
# V es la velocidad
#
# wV es velocidad el viento
#
# Cd es el coeficiente de drag
#
# A es el área efectiva
#
# Cr es el coeficiente de rozamiento
#
# $\%$ es la pendiente
#
# m es la masa total del conjunto bicicleta - ciclista

# %%
import os
import pandas as pd
import matplotlib.pylab as plt
# %matplotlib inline
plt.style.use('seaborn')
import numpy as np

# %% [markdown]
# ### Cargamos los datos

# %%
#path = '../Entrenamientos/result_tramos.xlsx'
path = '../Entrenamientos/Procesado_Tramos.xlsx'

# %%
df = pd.read_excel(path)

# %%
df.describe()
# Out:
#             tramo  tramo_inicial  tramo_final         pwr     time_seg  \
# count  286.000000     286.000000   286.000000  286.000000   286.000000
# mean    50.503497    3656.968531  3726.181818  165.837941   137.982517
# std     33.283129    2371.219515  2365.196496   68.757271   293.055632
# min      0.000000       0.000000    12.000000    0.000000     1.000000
# 25%     23.250000    1527.000000  1621.000000  111.587865    20.250000
# 50%     47.000000    3524.500000  3535.000000  172.968403    56.500000
# 75%     71.000000    6057.250000  6167.500000  220.269935   123.750000
# max    130.000000    7796.000000  7830.000000  394.699287  2761.000000
#
#                dist         spd  viento_aparente        porc      dist_acum
# count    286.000000  286.000000       285.000000  286.000000     286.000000
# mean     953.702177   30.246377        -0.335772         inf   50939.603808
# std     1556.607132    9.291600        11.029186         NaN   32672.602243
# min        0.000000    0.000000       -22.370389   -6.677410      80.820019
# 25%      129.987954   24.116650        -8.240294   -1.075459   21661.469741
# 50%      465.926543   29.889560        -1.853252   -0.013285   49151.450030
# 75%      900.805662   36.208949         7.204076    1.201687   84649.749962
# max    10273.070042   64.800000        22.925885         inf  107610.184614

# %%
df = df[df["viento_aparente"]!=-np.inf]
df = df[df["porc"]!=np.inf]
df["puntos_en_tramo"]= df["tramo_final"]-df["tramo_inicial"]
df = df[df["puntos_en_tramo"]>9]

# %%
df.describe()
# Out:
#             tramo  tramo_inicial  tramo_final         pwr     time_seg  \
# count  215.000000     215.000000   215.000000  215.000000   215.000000
# mean    49.674419    3553.102326  3644.139535  168.405062   181.558140
# std     33.872025    2375.163669  2370.575061   67.792295   326.618565
# min      0.000000       0.000000    12.000000   12.155189    10.000000
# 25%     21.000000    1385.500000  1517.000000  117.315016    47.000000
# 50%     47.000000    3489.000000  3538.000000  175.227708    75.000000
# 75%     70.500000    5860.500000  6115.000000  224.175701   164.000000
# max    130.000000    7796.000000  7830.000000  278.282728  2761.000000
#
#                dist         spd  viento_aparente        porc      dist_acum  \
# count    215.000000  215.000000       215.000000  215.000000     215.000000
# mean    1253.479693   30.288174        -0.219742   -0.062059   49790.914042
# std     1691.957461    9.363247        11.340914    2.506405   32718.435405
# min       86.820019    0.770052       -22.370389   -6.677410      80.820019
# 25%      398.384971   23.897223        -8.426241   -1.777627   20240.734819
# 50%      604.979958   29.712799        -1.141445   -0.303818   48515.000000
# 75%     1195.848355   36.520518         7.201207    1.727781   83865.653203
# max    10273.070042   52.825966        22.920272    7.137195  107610.184614
#
#        puntos_en_tramo
# count       215.000000
# mean         91.037209
# std         124.793918
# min          10.000000
# 25%          26.000000
# 50%          46.000000
# 75%          88.500000
# max         796.000000

# %%
df.head()
# Out:
#    tramo  tramo_inicial  tramo_final         pwr  time_seg         dist  \
# 0      0              0           65   74.149017       106   966.000000
# 1      1             65          432  255.588127       980  4819.000000
# 2      2            432          468  151.469326        44   473.935824
# 3      3            468          532  249.872906       120   813.223602
# 4      4            532          548  155.606266        21   206.720563
#
#          spd  viento_aparente      porc    dist_acum  \
# 0  32.807547         6.555296 -3.377386   948.878610
# 1  17.702449         7.198339  4.181100  5773.000000
# 2  38.776567         8.577246 -1.737873  6248.289894
# 3  24.396708         8.332607  2.662585  7051.000000
# 4  35.437811         8.261735 -0.873144  7270.977145
#
#                          prueba  puntos_en_tramo
# 0  20180406_LEVS_195_90_R_E.gpx               65
# 1  20180406_LEVS_195_90_R_E.gpx              367
# 2  20180406_LEVS_195_90_R_E.gpx               36
# 3  20180406_LEVS_195_90_R_E.gpx               64
# 4  20180406_LEVS_195_90_R_E.gpx               16

# %%
# Target=Spd

# %%
df_lm = df[['pwr','spd','porc','viento_aparente']]

# %%
df_lm_x = df[['pwr','porc','viento_aparente']]
df_lm_y = df[['spd']]

# %%
df_lm_x
# Out:
#            pwr      porc  viento_aparente
# 0    74.149017 -3.377386         6.555296
# 1   255.588127  4.181100         7.198339
# 2   151.469326 -1.737873         8.577246
# 3   249.872906  2.662585         8.332607
# 4   155.606266 -0.873144         8.261735
# 5   215.967082  1.566720         8.057656
# 6    80.232099 -1.730661         8.552635
# 7   220.019981  2.126107         7.115620
# 8    86.025963 -1.471857         7.314925
# 9   203.242003  0.946517         5.761689
# 10   50.593098 -2.440001         3.601057
# 11  172.746749  1.298545         6.496179
# 14   53.200088 -0.315241         0.775588
# 15  200.694391  2.748246        -0.836083
# 16   93.529880 -1.301930         8.358601
# 17  221.588084  0.941261         7.482789
# 18  142.031115 -0.170770         8.460267
# 19  239.264316  3.207283         5.944084
# 20  126.550233 -0.451470         7.204076
# 21  243.882193  7.137195         2.516139
# 22   55.477838 -6.677410        -0.011925
# 23  200.882921  4.067062         5.783767
# 24   88.421920 -1.276232         5.938477
# 25  126.581371  1.081617         3.631571
# 30   85.081177 -0.933150         5.892553
# 31  222.291330  5.870399         5.592770
# 32   58.170141 -5.723635        -5.663766
# 33  238.681748  2.290759        -0.596919
# 34  166.020893 -2.914999        -1.517217
# 35  215.401244  6.468743         5.388943
# ..         ...       ...              ...
# 37  245.106284  3.035196        -7.332985
# 38   99.068294 -2.353723        -9.430913
# 39  258.827080  4.766628        -9.175372
# 40  105.254951 -4.284866         9.687151
# 41  249.576634  2.314131         9.584947
# 42  127.616522 -3.191646         7.078100
# 43  255.774731  4.056833         7.583659
# 49  205.506036  0.859321         9.531972
# 50  188.291641 -0.599731         7.895037
# 51  229.357895  2.734965         7.916918
# 52  123.212955 -3.276340         9.441216
# 53  227.184909  3.130484         9.559288
# 54  109.001588 -0.417682         8.757905
# 55  193.473859  0.918666         9.412505
# 56  121.748248 -2.140538         9.445297
# 58  142.463180 -3.837103        -0.867769
# 60  150.388110 -2.184472         4.106524
# 61  242.359968  3.739678         9.783794
# 62  190.260948 -2.266873         0.361086
# 64  124.552543 -3.824229         6.389673
# 65  265.170246  2.057384         4.572991
# 66  174.304985 -3.070759        -7.556852
# 68  178.219641 -2.115367        -3.521114
# 69  278.282728  0.828080        -3.800165
# 70  213.937066 -1.666378        -3.875817
# 72   99.735092 -0.998905        -3.699759
# 73  162.136026  0.444191        -2.524485
# 75  184.873741  1.079441         0.761328
# 76   72.442941 -1.076144         3.456335
# 77  220.353253  2.314564        -5.486148
#
# [215 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(df_lm_x, df_lm_y, test_size=0.30, random_state=42)

# %% [markdown]
# ### RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score

# %%
rf = RandomForestRegressor(max_features=2, min_samples_split=4, n_estimators=50, min_samples_leaf=2)

# %%
rf.fit(X_train, Y_train)
Y_pred = rf.predict(X_test)
plt.scatter(Y_test, Y_pred)
plt.plot( [0,50],[0,50], c="red" )
# Out:
# C:\Users\eduardo.hernanz\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.

# %%
from sklearn.metrics import explained_variance_score
from sklearn.metrics import mean_squared_error


print(mean_squared_error(Y_test,Y_pred))
print(explained_variance_score(Y_test, Y_pred))
print(rf.feature_importances_)
# Out:
# 34.4531455831006
# 0.6131883372189456
# [0.18935578 0.68894757 0.12169665]

# %% [markdown]
# ### Preprocesamos y comparamos resultados con RFR

# %%
from sklearn.preprocessing import RobustScaler

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(df_lm_x, df_lm_y, test_size=0.30, random_state=42)

# %%
modelo_rs = RobustScaler()

# %%
X_train_rs = modelo_rs.fit_transform(X_train)

# %%
X_train_rs
# Out:
# array([[ 0.18746047,  0.38675183,  0.75491453],
#        [-1.05699948, -0.48959569, -1.03164256],
#        [ 0.84295452,  1.26233653,  0.44054759],
#        [-0.09476116, -0.2809241 ,  1.61103167],
#        [ 0.57901364,  0.21543988, -0.47287225],
#        [-0.46617237, -0.29847365, -0.34133934],
#        [-1.02490025,  0.05854386,  0.20602902],
#        [-0.7950813 , -0.51874612, -0.33824361],
#        [-0.04981053, -0.63296834,  0.06031875],
#        [ 0.21995688,  0.503756  , -0.38082444],
#        [ 0.5488793 ,  0.81070805,  0.43380287],
#        [-0.07327013,  0.56150136,  1.28601328],
#        [ 0.39193054,  0.62708183,  0.53088024],
#        [-0.77977565, -0.65861755, -0.38486997],
#        [ 0.80711932,  0.68964057,  0.44735817],
#        [-0.00873559, -0.81805173, -0.46721893],
#        [-0.0394532 , -0.11584211, -1.00100338],
#        [ 0.29597635,  0.06158231, -0.38236778],
#        [ 0.35244338,  0.57630914, -0.96990087],
#        [ 0.18940762, -0.20523299, -1.00993541],
#        [-0.27144451, -0.46911642,  0.00299248],
#        [-0.98194499, -1.38004001, -0.20319897],
#        [-0.91924491, -0.88007081,  0.45678386],
#        [ 0.2116268 ,  0.09594374,  1.61334787],
#        [-1.37964386, -1.40850519, -0.59731433],
#        [-0.17557708, -0.3198633 ,  0.70183288],
#        [ 0.63448707,  0.28500068, -0.88631613],
#        [ 0.41217337,  0.65205601, -0.39101231],
#        [-0.85858777, -0.14384948,  0.37639342],
#        [-0.93797473, -0.62866803,  1.51676569],
#        [-0.85482718, -0.00448927, -0.5930882 ],
#        [ 0.46255062,  0.48824051, -0.93079943],
#        [ 0.61231679,  0.93947654, -0.35460164],
#        [ 0.24179903,  0.30478524, -0.38860415],
#        [ 0.58610903,  0.85681761,  1.58719954],
#        [-0.59368159, -0.39260893, -0.41990622],
#        [-0.72048435, -0.19707114,  0.53413628],
#        [-0.31658709, -0.46722409,  0.54808901],
#        [-1.21546474, -0.38339468,  1.56798723],
#        [-0.07915715, -0.01552823, -0.29263523],
#        [ 0.00831982,  0.48779614,  0.56957884],
#        [ 0.36432025, -0.30084624, -0.08957281],
#        [-0.47536078,  0.00897913,  0.59481898],
#        [-0.79126749, -0.31794516,  0.70026889],
#        [ 0.57818404,  0.75171609,  0.11880473],
#        [ 0.47881895,  0.97507525,  0.76424275],
#        [ 0.02178738, -0.674399  , -0.32350664],
#        [-0.39734135, -0.80944353,  0.64849759],
#        [-0.13982225, -0.08985341,  0.68178184],
#        [ 0.21439747,  0.62104686, -0.3360248 ],
#        [-0.18492183, -0.4386548 ,  0.41771364],
#        [-0.58913185, -0.7822967 , -1.07383329],
#        [ 0.6921187 ,  0.84658428,  0.03896336],
#        [-0.45532358, -0.3410118 , -0.78669992],
#        [ 0.72595293,  0.63398571,  1.5002676 ],
#        [-1.04743199, -0.5066231 ,  0.38559068],
#        [ 0.36256048,  0.5318035 , -0.23669335],
#        [ 0.0297623 ,  0.20748129,  0.76063711],
#        [ 0.19304364,  0.58289128, -1.14604006],
#        [ 0.2108552 , -0.68477164, -0.45249996],
#        [-0.84384246, -0.75595903,  0.57333578],
#        [ 0.1426715 , -0.01712784,  0.6584778 ],
#        [ 0.10080058, -0.204874  ,  0.1104646 ],
#        [-1.12522233, -0.03607466, -0.43825021],
#        [ 0.41514385, -0.01304273, -0.44610856],
#        [-0.76097159, -0.44372879, -0.00299248],
#        [ 0.32883745,  0.33033664, -0.36259054],
#        [ 0.55206144,  0.46147912,  0.26285834],
#        [-0.02620663,  0.45578431, -0.3441073 ],
#        [ 0.47917804,  1.18238445,  1.34179584],
#        [-0.39067915,  0.43009545,  0.38752987],
#        [ 0.01955383, -0.17329859, -0.41661515],
#        [ 0.29145239,  0.37096667,  0.76250676],
#        [ 0.86852159,  0.84882918, -0.76837324],
#        [-0.60285966, -0.21472409, -0.33773155],
#        [ 0.70176373,  0.2205106 , -0.28648935],
#        [-0.91889471, -0.11869667, -0.34114089],
#        [-0.18847971,  0.0214362 , -0.17931571],
#        [ 0.50454768,  0.18111014,  0.31009537],
#        [-0.1498116 , -0.160713  , -0.35991643],
#        [ 0.71212894,  0.52845121,  0.7166912 ],
#        [ 0.67490719,  0.85061845,  0.68628583],
#        [-0.42434223, -0.0358752 ,  1.09927736],
#        [-1.09656367, -1.11901613, -0.29388635],
#        [-0.70986899, -0.09719313, -0.16104991],
#        [ 0.49759967,  0.86987096,  0.65986834],
#        [ 0.67454416,  0.79369355,  0.55993723],
#        [-0.43245095, -0.42696869,  0.75699852],
#        [-0.85256077, -0.50047182, -0.38919138],
#        [ 0.8037978 ,  0.0911231 , -1.13082778],
#        [-0.37027134,  0.28807212, -0.32101461],
#        [ 0.41689378,  0.70792012,  0.60894502],
#        [ 0.55536161,  0.37078973,  1.61195189],
#        [ 0.39148695,  0.86975254, -0.76711991],
#        [ 0.2145405 ,  0.56989321, -0.42824307],
#        [-0.38173253, -0.70655368,  0.60656058],
#        [-0.41979176, -0.72908159,  0.75673918],
#        [-0.15879407,  0.29190733,  0.3612835 ],
#        [-0.74119217, -0.24910544,  0.62161104],
#        [ 0.24986621,  0.8734036 ,  0.10360556],
#        [-0.64747557, -0.49023275, -1.1548133 ],
#        [-0.64343651, -1.11507261, -0.2748696 ],
#        [-0.3745789 , -0.14182631, -0.82245728],
#        [ 0.58321907,  0.99550308,  0.53449258],
#        [-0.13578461, -0.1392611 ,  0.42986216],
#        [-1.20448129, -0.84401024, -1.14163865],
#        [ 0.92044812,  0.36265682, -0.08476504],
#        [ 0.35157665,  0.76639336,  0.53098577],
#        [ 0.70523353,  1.04335928, -0.44178795],
#        [-0.54261802,  0.03129535,  0.71331399],
#        [-1.06638975, -0.56403668, -0.31667184],
#        [-0.16847541, -0.02559941, -0.38852406],
#        [-0.64124015, -0.29273583,  1.59767434],
#        [ 0.32191328,  0.29722379, -0.30964507],
#        [ 0.62757185,  0.87727277, -0.05186762],
#        [-0.08338673,  0.26054586, -0.00369421],
#        [ 0.76401219,  1.25851713,  0.53778034],
#        [ 0.33078111,  1.02570904,  0.02436393],
#        [-0.1459857 ,  0.19213008, -0.34466046],
#        [-0.87624602, -0.08202605, -0.1907435 ],
#        [ 0.25149565,  1.22419671,  0.52430425],
#        [-1.10934684, -0.62870723,  1.28928939],
#        [ 0.87322924,  0.82137432, -0.05675844],
#        [ 0.05562103, -0.4202733 , -0.06703106],
#        [ 0.75229648,  1.41027488, -0.42636531],
#        [-0.73853716, -0.76692814, -0.78626352],
#        [-0.53314854, -0.07417421, -0.36170753],
#        [-1.2571572 , -0.99549381, -0.87341536],
#        [ 0.15969187, -0.46057263,  0.179687  ],
#        [ 0.7243028 ,  1.25452956,  0.61420185],
#        [ 0.43560536,  0.65427916, -0.38785983],
#        [-0.15138672, -0.58167967,  0.18845434],
#        [ 0.29859462,  0.19267706, -0.52001444],
#        [-0.53936343, -0.53795974, -0.31956499],
#        [-1.09235705, -0.87861317,  1.29318785],
#        [ 0.45082407,  0.63067229,  1.46396459],
#        [ 0.00344019, -0.14312058,  1.56791889],
#        [ 0.13258874,  0.63469764,  0.08794247],
#        [ 0.60997423,  1.13711552,  0.77851036],
#        [ 0.17934582, -0.03006177, -1.26492308],
#        [-0.79140686, -0.13131541,  1.51383228],
#        [ 0.41977419,  0.75804811, -0.19191109],
#        [-1.00521407, -1.63373529,  0.15598174],
#        [-0.57499952, -0.99734034,  0.7723686 ],
#        [ 0.83915701,  0.86012669, -1.11927929],
#        [ 0.09806693,  0.28746812,  1.60682595],
#        [-0.67633718, -0.20390648,  0.6879378 ],
#        [ 0.16879826,  0.53815909, -0.65836283],
#        [-0.00344019, -0.57456221, -0.33578144],
#        [-0.31186265,  0.00448927,  1.07953294]])

# %%
X_test_rs = modelo_rs.transform(X_test)

# %%
X_test_rs
# Out:
# array([[-0.25341556, -0.8782395 ,  0.10159187],
#        [ 0.11313122,  0.42951665,  0.20512278],
#        [ 0.81839204,  0.6735551 ,  0.05758837],
#        [ 0.55591418,  0.36253362, -0.41598655],
#        [ 0.43044661,  0.39276187,  0.63227897],
#        [-0.03897182, -0.01805533,  1.6107712 ],
#        [-0.18002171, -0.05158649,  0.51778624],
#        [ 0.59664979,  0.57722402, -1.03533395],
#        [-0.40821395, -0.87481502,  0.56281024],
#        [ 0.00820288, -0.06223704,  0.51656201],
#        [ 0.41681722, -0.23181636,  0.46833883],
#        [-1.18990902, -1.58620577, -0.217446  ],
#        [-0.62846968, -0.4836739 , -0.44260523],
#        [ 0.27188476,  0.39415995,  0.52290122],
#        [ 0.64795404,  0.95386466,  0.06225142],
#        [-0.05262729, -0.08501832, -0.42268994],
#        [ 0.73238921,  1.12566032, -0.23745558],
#        [-0.39094827,  0.02230821,  0.61456648],
#        [-0.12158501,  0.24130507, -0.53480498],
#        [-0.65877429, -0.44338509,  0.08531839],
#        [ 0.63371014,  0.94972955, -0.30927963],
#        [ 0.75608688,  0.8171875 ,  0.04777172],
#        [ 0.85503948,  0.26491405, -1.1198899 ],
#        [ 0.43652463,  1.70386776,  0.51216622],
#        [ 0.02694143,  0.42714582,  1.25962488],
#        [-0.12303001, -0.212352  , -0.55741987],
#        [ 0.67234656,  0.75793283,  0.76587339],
#        [-0.25714983,  0.09697173,  0.69439879],
#        [-0.36454771, -0.08523872, -0.36694013],
#        [ 0.38427673,  0.4622174 , -0.37356017],
#        [ 0.62458932,  0.76708901,  1.49236055],
#        [ 0.04461701,  0.86485015, -0.24941901],
#        [ 0.35058991,  0.50016067,  1.61218836],
#        [ 0.72591558,  1.22147586,  0.6386894 ],
#        [ 0.48009662,  1.59280087,  1.20963683],
#        [ 0.165153  ,  0.18030902,  1.01824576],
#        [ 0.37903053,  0.52693533, -1.17632744],
#        [-0.32128503, -0.12857379,  0.25929696],
#        [ 0.0888532 ,  0.03362675,  1.44002713],
#        [-1.05291976, -1.26660606,  1.16619357],
#        [-1.24711623, -1.27393231,  0.2715228 ],
#        [-0.10872377, -0.35716985, -0.45468987],
#        [ 0.54929935,  0.21711391,  1.56707632],
#        [ 0.59581217,  1.1335664 , -0.24727797],
#        [-0.55397088, -0.25827612, -1.18276131],
#        [ 0.71734789,  1.46971618,  0.15602923],
#        [-0.36055761, -0.49151621,  0.30849058],
#        [-0.62270667, -0.12330467, -0.07838414],
#        [-0.28553244, -0.34993312, -0.51321845],
#        [ 0.54489835,  0.38936454,  0.13545505],
#        [ 0.2549404 , -0.06611792, -0.30863178],
#        [ 0.15034032,  0.32574704, -0.37669   ],
#        [-0.74935779, -0.10581429,  0.53121775],
#        [ 0.68208101,  0.49954219,  0.40820178],
#        [ 0.45479775,  0.67835924,  1.53441727],
#        [ 0.37697487,  1.86302195,  0.49921279],
#        [ 0.62313054,  2.04082403,  0.31664292],
#        [ 0.08508331,  0.73425791, -0.40607458],
#        [-0.66020582,  0.7571712 ,  0.08419952],
#        [ 0.65617246,  0.27594717, -0.4606531 ],
#        [-0.38689861,  0.04101906, -0.1451258 ],
#        [ 0.38186531,  0.55912838,  0.66881243],
#        [ 0.72214195,  0.53516387,  0.1996419 ],
#        [-0.68257074, -0.39570926, -0.32197962],
#        [-1.01608916, -0.70457749,  1.26201319]])

# %%
rf_robust = RandomForestRegressor(max_features=2, min_samples_split=4, n_estimators=50, min_samples_leaf=2)

# %%
rf_robust.fit(X_train_rs,Y_train)
Y_pred = rf_robust.predict(X_test_rs)
# Out:
# C:\Users\eduardo.hernanz\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.

# %%
plt.scatter(Y_test, Y_pred)
plt.plot( [0,50],[0,50], c="red" )

# %%
print(mean_squared_error(Y_test,Y_pred))
print(explained_variance_score(Y_test, Y_pred))
print(rf.feature_importances_)
# Out:
# 35.11256711146977
# 0.6060128998067833
# [0.18935578 0.68894757 0.12169665]

# %%
#Grid Search con RFR

# %%
from sklearn.model_selection import GridSearchCV
#max_features=2, min_samples_split=4, n_estimators=50, min_samples_leaf=2
rfr = RandomForestRegressor(n_jobs=1, random_state=0, max_features=3)
param_grid = {'n_estimators': [1000]}
# 'n_estimators': [1000], 'max_features': [10,15,20,25], 'max_depth':[20,20,25,25,]}
model = GridSearchCV(estimator=rfr, param_grid=param_grid, n_jobs=1, cv=10)

model.fit(X=X_train, y=Y_train)
print('Random forecast regression...')
print('Best Params:')
print(model.best_params_)
print('Best CV Score:')
print(model.best_score_)



Y_pred = model.predict(X_test)
# Out:
# C:\Users\eduardo.hernanz\AppData\Local\Continuum\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\eduardo.hernanz\AppData\Local\Continuum\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\eduardo.hernanz\AppData\Local\Continuum\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\eduardo.hernanz\AppData\Local\Continuum\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\eduardo.hernanz\AppData\Local\Continuum\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\eduardo.hernanz\AppData\Local\Continuum\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\eduardo.hernanz\AppData\Local\Continuum\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\eduardo.hernanz\AppData\Local\Continuum\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\eduardo.hernanz\AppData\Local\Continuum\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\eduardo.hernanz\AppData\Local\Continuum\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\eduardo.hernanz\AppData\Local\Continuum\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:739: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.best_estimator_.fit(X, y, **fit_params)
# Random forecast regression...
# Best Params:
# {'n_estimators': 1000}
# Best CV Score:
# 0.5827166123239478

# %%
print(mean_squared_error(Y_test,Y_pred))
print(explained_variance_score(Y_test, Y_pred))
print(rf.feature_importances_)
# Out:
# 31.3286053881597
# 0.6481208438848317
# [0.18935578 0.68894757 0.12169665]

# %%
pwr
porc
viento_aparente
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-160c8dbf306c> in <module>()
# ----> 1 pwd
#       2 porc
#       3 viento_aparente
#
# NameError: name 'pwd' is not defined

# %%
model.predict([[250,3,0]])
# Out:
# array([23.96049222])

# %%
from sklearn.externals import joblib
joblib.dump(model, "modelo_export.model")
# Out:
# ['modelo_export.model']

# %%
plt.scatter(Y_test, Y_pred)
plt.plot( [0,70],[0,70], c="red" )

# %%
metrics.explained_variance_score(Y_test, Y_pred)
# Out:
# 0.59974295184543747
