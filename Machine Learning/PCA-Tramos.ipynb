# %% [markdown]
# ### PCA

# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import plotly.offline as py
import plotly.graph_objs as go

# %%
py.init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
df_total = pd.read_excel("../Entrenamientos/result_tramos.xlsx")

# %%
df_total = df_total[df_total["sp_vel_aparente"]!=-np.inf]

# %%
df_total.describe()
# Out:
#            tramo  tramo_inicial  tramo_final      sp_pwd  tiempo_tramo  \
# count  75.000000      75.000000    75.000000   75.000000     75.000000
# mean   37.480000    4423.960000  4524.800000  146.697211    230.786667
# std    22.231193    2557.723182  2529.893951   66.803668    497.567768
# min     0.000000       0.000000    65.000000    0.000000      2.000000
# 25%    18.500000    1297.500000  1654.000000   88.168538     21.500000
# 50%    37.000000    5927.000000  5935.000000  157.112154     70.000000
# 75%    56.500000    6590.500000  6591.500000  202.654265    142.000000
# max    75.000000    7478.000000  7564.000000  255.381555   2761.000000
#
#        distancia_tramo   vel_calc  sp_vel_aparente  porcent_des
# count        75.000000  75.000000        75.000000    75.000000
# mean       1404.350534  27.268971        -1.000097     0.024593
# std        2419.973943   8.964338         6.867127     2.433537
# min          11.000000   0.770052        -9.859221    -6.677410
# 25%         112.189268  21.643902        -7.377288    -0.957365
# 50%         478.200000  27.282754        -2.994640    -0.030749
# 75%         890.626216  32.798548         5.298305     1.014067
# max       10273.070042  50.116364        18.939865     7.137195

# %%
x=np.array(df_total['sp_pwd'])

# %%
y=np.array(df_total['vel_calc'])

# %%
z=np.array(df_total['porcent_des'])

# %%
py.iplot([go.Scatter3d(x=x,y=y,z=z,mode='markers',marker=dict(color=np.array(df_total['sp_vel_aparente']),size=5))])
# Out:
# <div id="58774349-da87-4de5-9be0-fec18f5e82d2" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("58774349-da87-4de5-9be0-fec18f5e82d2", [{"type": "scatter3d", "x": [77.83618579538232, 255.3815552863136, 152.194251992272, 248.7704342963505, 155.7532568635691, 217.0737447598807, 81.67073076419639, 219.5772386316629, 87.14700858201383, 202.9785592614028, 50.30865741202978, 168.3655465558334, 4.0, 0.0, 53.20008762769232, 201.8601050198477, 102.6816041281018, 211.3675709629391, 149.5574512158791, 239.1621927249502, 126.5634970103778, 243.8045997243375, 55.688525551422, 200.4906291107062, 92.89480770119172, 131.522378308617, 239.4097408, 187.857244733762, 202.3299712, 72.24375329057187, 93.67807572079727, 221.5514325326825, 59.49330754774205, 234.6930540031643, 165.8781628560764, 215.3398847683529, 34.10807880496218, 55.42734536565504, 50.46450309465352, 115.3838298094053, 199.8398256322458, 163.6690160162539, 126.0066190344796, 80.08780254543153, 203.0783598878402, 107.3940527847715, 185.1664108473684, 104.9571158558158, 163.7924131564235, 206.5609191388731, 194.4535423486665, 157.1121538636445, 89.1900672, 133.2654555206682, 188.7898752, 254.9076623146455, 68.5366656, 227.9320749296184, 206.1735927836718, 129.5757652625317, 220.1667031927183, 65.32445243150657, 161.6857207804906, 109.5925262152852, 104.299885784053, 79.0075975129708, 195.9332080588642, 84.1671040467582, 218.3210943498727, 45.80740601571158, 181.971081394345, 177.8400192, 162.4786213828015, 151.3407796106418, 176.1562457672205], "y": [32.80754716981132, 17.70244897959184, 38.7765673907564, 24.39670806006297, 35.43781081186982, 26.91783553264644, 36.10140845070423, 22.79205298013245, 32.62, 27.13846153846154
#          -7.71067502e+00],
#        [  1.07394053e+02,   2.64499682e+01,  -8.14197941e-01,
#          -7.35942116e+00],
#        [  1.85166411e+02,   2.35184113e+01,   6.89316745e-01,
#          -4.76283572e+00],
#        [  1.04957116e+02,   2.96669743e+01,  -1.34259896e+00,
#          -2.82688350e+00],
#        [  1.63792413e+02,   2.47577104e+01,   1.17819535e+00,
#          -5.64236321e+00],
#        [  2.06560919e+02,   7.70052302e-01,  -3.03817643e-01,
#          -5.12053225e+00],
#        [  1.94453542e+02,   2.13585574e+01,   1.35854621e+00,
#          -4.54382295e+00],
#        [  1.57112154e+02,   3.26115528e+01,  -1.13954282e+00,
#          -3.52683770e+00],
#        [  8.91900672e+01,   2.98828246e+01,   4.53791378e-02,
#          -4.71085751e+00],
#        [  1.33265456e+02,   3.27895493e+01,  -1.90229713e-01,
#          -3.51458301e+00],
#        [  1.88789875e+02,   3.43798795e+01,   1.14959306e-01,
#          -2.62227869e+00],
#        [  2.54907662e+02,   3.13740979e+01,  -5.84320565e-02,
#          -2.99463976e+00],
#        [  6.85366656e+01,   1.88777623e+01,   1.28013810e-01,
#          -4.12735520e+00],
#        [  2.27932075e+02,   3.65317516e+01,  -6.25100078e-02,
#          -3.71070152e+00],
#        [  2.06173593e+02,   2.97127986e+01,   7.06571447e-01,
#          -3.71734872e+00],
#        [  1.29575765e+02,   3.25717181e+01,  -8.55795271e-01,
#          -8.00257795e+00],
#        [  2.20166703e+02,   2.25738018e+01,   1.91608405e+00,
#          -8.16709686e+00],
#        [  6.53244524e+01,   2.72827541e+01,  -9.81581316e-01,
#          -9.55310428e+00],
#        [  1.61685721e+02,   2.59556813e+01,   1.86980193e-01,
#          -8.58305837e+00],
#        [  1.09592526e+02,   2.31781520e+01,  -4.53466057e-01,
#          -9.54400326e+00],
#        [  1.04299886e+02,   3.30532300e+01,   1.82683777e-02,
#          -6.77830586e+00],
#        [  7.90075975e+01,   3.69672543e+01,  -2.41687525e+00,
#          -8.41676619e+00],
#        [  1.95933208e+02,   2.69713713e+01,   5.82082796e-01,
#          -9.61908687e+00],
#        [  8.41671040e+01,   3.96434085e+01,  -3.01142835e+00,
#          -8.35641016e+00],
#        [  2.18321094e+02,   2.45931429e+01,   1.92444205e+00,
#          -8.44942444e+00],
#        [  4.58074060e+01,   5.01163644e+01,  -4.74230918e+00,
#          -5.20955434e+00],
#        [  1.81971081e+02,   3.90599808e+01,   1.47881274e-01,
#           2.75364932e+00],
#        [  1.77840019e+02,   2.97899712e+01,  -6.54026845e-02,
#          -3.43291768e-01],
#        [  1.62478621e+02,   3.30300673e+01,   9.26210578e-02,
#          -2.16317258e+00],
#        [  1.51340780e+02,   3.32088375e+01,  -6.31579673e-01,
#          -7.40034884e+00],
#        [  1.76156246e+02,   1.62698997e+01,   2.71608932e+00,
#          -7.39515512e+00]])

# %%
#vamos con PCA
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)

# %%
X_enc=pca.fit_transform(X_df)

# %%
py.iplot(([go.Scatter(x=X_enc[:,0],y=X_enc[:,1],mode='markers',marker=dict(color=np.array(df_total['sp_vel_aparente']),size=5))]))
# Out:
# 'file://D:\\Documents\\AnacondaProjects\\Project_TFM\\IM_KS\\Machine Learning\\temp-plot.html'

# %%
py.iplot(([go.Scatter(x=X_enc[:,0],y=X_enc[:,1],mode='markers',marker=dict(color=np.array(df_total['porcent_des']),size=5))]))
# Out:
# 'file://D:\\Documents\\AnacondaProjects\\Project_TFM\\IM_KS\\Machine Learning\\temp-plot.html'

# %%
py.iplot(([go.Scatter(x=X_enc[:,0],y=X_enc[:,1],mode='markers',marker=dict(color=np.array(df_total['vel_calc']),size=5))]))
# Out:
# 'file://D:\\Documents\\AnacondaProjects\\Project_TFM\\IM_KS\\Machine Learning\\temp-plot.html'

# %%
py.iplot(([go.Scatter(x=X_enc[:,0],y=X_enc[:,1],mode='markers',marker=dict(color=np.array(df_total['sp_pwd']),size=5))]))
# Out:
# 'file://D:\\Documents\\AnacondaProjects\\Project_TFM\\IM_KS\\Machine Learning\\temp-plot.html'

# %% [markdown]
# ### MULTIDIMENSIONAL SCALING

# %%
#Vemos distancias entre puntos

# %%
from sklearn.metrics.pairwise import pairwise_distances

# %%
d = pairwise_distances(X_df)
#d = pairwise_distances(X[:5])

# %%
plt.figure(figsize=(10,10))
plt.imshow(d)

# %%
#Aplicamos el MDS

# %%
#Tarda mucho. No ejecutar

# %%
from sklearn.manifold import MDS

# %%
X_df2 = df_total[['sp_pwd','vel_calc','porcent_des']].values

# %%
mds=MDS(n_components=2)

# %%
X_enc=mds.fit_transform(X_df2)

# %%
py.plot(([go.Scatter(x=X_enc[:,0],y=X_enc[:,1],mode='markers',marker=dict(color=np.array(df_total['sp_vel_aparente']),size=5))]))
# Out:
# 'file://D:\\Documents\\AnacondaProjects\\Project_TFM\\IM_KS\\Machine Learning\\temp-plot.html'

# %%
py.plot(([go.Scatter(x=X_enc[:,0],y=X_enc[:,1],mode='markers',marker=dict(color=np.array(df_total['vel_calc']),size=5))]))
# Out:
# 'file://D:\\Documents\\AnacondaProjects\\Project_TFM\\IM_KS\\Machine Learning\\temp-plot.html'

# %%
py.plot(([go.Scatter(x=X_enc[:,0],y=X_enc[:,1],mode='markers',marker=dict(color=np.array(df_total['porcent_des']),size=5))]))
# Out:
# 'file://D:\\Documents\\AnacondaProjects\\Project_TFM\\IM_KS\\Machine Learning\\temp-plot.html'

# %%
py.plot(([go.Scatter(x=X_enc[:,0],y=X_enc[:,1],mode='markers',marker=dict(color=np.array(df_total['sp_pwd']),size=5))]))
# Out:
# 'file://D:\\Documents\\AnacondaProjects\\Project_TFM\\IM_KS\\Machine Learning\\temp-plot.html'

# %%
#ISOMAP

# %%
from sklearn.manifold import isomap

# %%
iso = isomap.Isomap(n_components=2)

# %%
X_enc=iso.fit_transform(X_df2)

# %%
py.plot(([go.Scatter(x=X_enc[:,0],y=X_enc[:,1],mode='markers',marker=dict(color=np.array(df_total['sp_vel_aparente']),size=5))]))
# Out:
# 'file://D:\\Documents\\AnacondaProjects\\Project_TFM\\IM_KS\\Machine Learning\\temp-plot.html'

# %%
py.plot(([go.Scatter(x=X_enc[:,0],y=X_enc[:,1],mode='markers',marker=dict(color=np.array(df_total['sp_pwd']),size=5))]))
# Out:
# 'file://D:\\Documents\\AnacondaProjects\\Project_TFM\\IM_KS\\Machine Learning\\temp-plot.html'

# %%
py.plot(([go.Scatter(x=X_enc[:,0],y=X_enc[:,1],mode='markers',marker=dict(color=np.array(df_total['vel_calc']),size=5))]))
# Out:
# 'file://D:\\Documents\\AnacondaProjects\\Project_TFM\\IM_KS\\Machine Learning\\temp-plot.html'

# %%
py.plot(([go.Scatter(x=X_enc[:,0],y=X_enc[:,1],mode='markers',marker=dict(color=np.array(df_total['porcent_des']),size=5))]))
# Out:
# 'file://D:\\Documents\\AnacondaProjects\\Project_TFM\\IM_KS\\Machine Learning\\temp-plot.html'

# %% [markdown]
# ### T-SNE

# %%
#PUNTOS LEJANOS CUANDO SON ACERCADOS NO PENALIZA
#PUNTOS CERCANOS SI LOS ALEJA PENALIZA MUCHO
#SE BASA EN PROBABILIDADES DE QUE UN PUNTO ESTE CERCA DE OTRO PUNTO

# %%
X_df2
# Out:
# array([[   0.        ,    5.        ,    0.        ],
#        [   0.        ,    5.14174814,  -11.73132446],
#        [   0.        ,    5.19999981,    1.39853274],
#        ...,
#        [ 153.8       ,    7.46000004,   -2.65256559],
#        [ 163.59985034,    7.30000019,    2.54632635],
#        [ 137.        ,    7.30000019,    0.        ]])

# %%
from sklearn.manifold import TSNE

# %%
tsne = TSNE(n_components=2)

# %%
X_enc=tsne.fit_transform(X_df2)

# %%
py.plot(([go.Scatter(x=X_enc[:,0],y=X_enc[:,1],mode='markers',marker=dict(color=np.array(df_total['sp_vel_aparente']),size=5))]))
# Out:
# 'file://D:\\Documents\\AnacondaProjects\\Project_TFM\\IM_KS\\Machine Learning\\temp-plot.html'

# %%
py.plot(([go.Scatter(x=X_enc[:,0],y=X_enc[:,1],mode='markers',marker=dict(color=np.array(df_total['sp_pwd']),size=5))]))
# Out:
# 'file://D:\\Documents\\AnacondaProjects\\Project_TFM\\IM_KS\\Machine Learning\\temp-plot.html'

# %%
py.plot(([go.Scatter(x=X_enc[:,0],y=X_enc[:,1],mode='markers',marker=dict(color=np.array(df_total['vel_calc']),size=5))]))
# Out:
# 'file://D:\\Documents\\AnacondaProjects\\Project_TFM\\IM_KS\\Machine Learning\\temp-plot.html'

# %%
py.plot(([go.Scatter(x=X_enc[:,0],y=X_enc[:,1],mode='markers',marker=dict(color=np.array(df_total['porcent_des']),size=5))]))
# Out:
# 'file://D:\\Documents\\AnacondaProjects\\Project_TFM\\IM_KS\\Machine Learning\\temp-plot.html'

# %%
#vamos con TSNE
from sklearn.manifold import TSNE

# %%
tsne3d = TSNE(n_components=3)

# %%
X_enc_3d=tsne3d.fit_transform(X_df2)

# %%
py.plot([go.Scatter3d(x=X_enc_3d[:,0],y=X_enc_3d[:,1],z=X_enc_3d[:,2],mode='markers',marker=dict(color=np.array(df_total['sp_pwd']),size=5))])
# Out:
# 'file://D:\\Documents\\AnacondaProjects\\Project_TFM\\IM_KS\\Machine Learning\\temp-plot.html'

# %%
X_enc_3d
# Out:
# array([[ 174.85075378,  -12.43148041, -157.32437134],
#        [ -84.73188782, -145.77854919, -139.44334412],
#        [ 183.84925842,   83.75721741, -103.12800598],
#        [-211.40951538, -353.68121338,  189.28068542],
#        [-147.51795959,   37.7253418 , -130.33436584],
#        [ -34.54995728,  192.55747986,  -75.30099487],
#        [  65.51920319,  145.88056946, -154.58236694],
#        [ 157.42172241,  199.38101196, -111.31178284],
#        [-119.09355164, -173.0533905 ,  -29.21006775],
#        [ -26.10897636,  -42.3052597 ,  271.29898071],
#        [-126.77222443, -119.81118774,   64.71005249],
#        [ -51.12429428,   26.35881042, -163.57080078],
#        [  25.86698723, -150.76210022, -224.81529236],
#        [-202.21768188,   96.62503052,  100.51941681],
#        [ 203.6459198 ,  -33.24499512,   97.25278473],
#        [ -25.01448631, -188.3377533 ,  112.38352203],
#        [ -18.25240326, -234.80123901,  -41.49599457],
#        [  50.35377502, -218.30329895, -131.86032104],
#        [ -46.08896637,  -70.34934998,  -26.18999481],
#        [  50.22807312,  240.58872986,  -46.94571304],
#        [ 103.70076752, -161.19923401,   91.83076477],
#        [  93.25389862,  -74.55908203,   16.16061592],
#        [-102.50405121,   84.19733429,  133.06225586],
#        [  50.28863525, -123.79647064,  -69.78892517],
#        [ -19.79297066, -162.14627075,   10.4805069 ],
#        [  10.58791924,  120.36463928,   -3.92121506],
#        [ -57.44431686,  -72.07035828,  158.70391846],
#        [  36.82944489,   48.41618729, -106.23617554],
#        [  97.38967133,  164.22991943,   74.79096222],
#        [-144.71902466,   -4.44945526,   89.68991852],
#        [-205.82875061,  -53.52581024,   20.79784775],
#        [-139.65480042,  160.96894836, -105.46479034],
#        [-198.89042664,   70.64498901,   -7.77012014],
#        [ 122.53942871,   31.89856148,   44.02273178],
#        [ -47.68320084,  121.18321228, -166.91610718],
#        [ 211.41818237,  536.62097168, -220.41958618],
#        [ -90.84170532,  375.82543945,  313.26647949],
#        [ 446.84881592,  166.9745636 , -454.54882812],
#        [-151.88500977,   62.43964386,  344.35565186],
#        [ -88.55804443,   25.66561127,  206.27532959],
#        [ 102.7277298 ,   66.68834686,  -39.62035751],
#        [   6.24370575,    8.56600285,  -16.23902702],
#        [ -70.21703339,   92.83005524,   33.56218719],
#        [  -7.81879759,  -92.42106628,   68.86367035],
#        [  33.37611008,  -17.27510834,  200.48638916],
#        [ 222.24819946,    1.95923209,  -22.16963196],
#        [ 129.29858398,  -18.50618744,  175.14575195],
#        [  62.06774521, -275.91247559,   10.02850628],
#        [-106.69244385,    5.6108098 ,  -15.96639538],
#        [ 110.95033264,  -29.97610474,  -67.1234436 ],
#        [ -28.67059708, -279.75579834,  105.04750061],
#        [ -72.36797333,  -28.9430809 ,  -98.14762878],
#        [ 104.7756958 , -193.9941864 ,   -9.52269077],
#        [ -61.20360947,  -64.85571289, -209.25189209],
#        [ -20.7887001 ,  288.56387329,  428.15789795],
#        [  31.90359688,  -55.2022438 , -141.00694275],
#        [  87.96768188,  -37.24337769, -361.09957886],
#        [ 181.19256592, -116.9732132 ,  -82.92353821],
#        [ 124.76304626,  159.32052612,  -21.82768059],
#        [ -99.64916992,  182.23384094,   28.31366539],
#        [  14.2709446 ,   26.85501862, -247.38330078],
#        [ -48.81565857,   -3.39669895,   82.53005219],
#        [  56.12416458, -122.5166626 ,  175.50392151],
#        [ -30.04939079,  168.16439819,  115.55596924],
#        [  19.55888748,   78.96349335,   90.22734833],
#        [ 205.73175049,   91.01980591,   76.49507904],
#        [ 191.9354248 , -115.80683899,   23.23226738],
#        [ 111.32279205,   55.85198593, -203.43659973],
#        [ 115.90415955, -114.47775269, -160.00242615],
#        [-188.025177  ,  -77.61122131,  142.08740234],
#        [  60.76672363,  -21.29192352,   99.93498993],
#        [-168.51011658,  -59.86669159,  -86.54256439],
#        [  56.78628922,   91.50814056,  187.45573425],
#        [ -64.27875519,   73.77703094,  -68.56770325],
#        [ -62.61743546, -157.62944031,  211.13891602]], dtype=float32)

# %%
df_total['x_tsne']=0
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-82-636d167d2c30> in <module>()
# ----> 1 X_df['x_tsne']=0
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
kk = X_enc_3d[:,0]

# %%
len(X_df)
# Out:
# 75

# %%
len(X_enc_3d[:,0])
# Out:
# 75

# %%
kk2 = kk.tolist()
type(kk2)
# Out:
# list

# %%
X_df
# Out:
# array([[   0.        ,    5.        ,    0.        ,    0.        ],
#        [   0.        ,    5.14174814,  -11.73132446,    9.36322184],
#        [   0.        ,    5.19999981,    1.39853274,    9.81721966],
#        ...,
#        [ 153.8       ,    7.46000004,   -2.65256559,   -9.87517531],
#        [ 163.59985034,    7.30000019,    2.54632635,   -9.92730837],
#        [ 137.        ,    7.30000019,    0.        ,   -9.96827011]])

# %%
X_df_clust=df_total[['sp_pwd','vel_calc','porcent_des','sp_vel_aparente']]

# %%
X_df_clust['x_tsne']=X_enc_3d[:,0]
X_df_clust['y_tsne']=X_enc_3d[:,1]
X_df_clust['z_tsne']=X_enc_3d[:,2]
# Out:
# C:\Users\eduardo.hernanz\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\eduardo.hernanz\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\eduardo.hernanz\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
X_df_clust.to_csv('tramos_ml_pca.csv')

# %%
X_df_clust
# Out:
#         sp_pwd   vel_calc  porcent_des  sp_vel_aparente      x_tsne  \
# 0    77.836186  32.807547    -3.377386         8.396543  174.850754
# 1   255.381555  17.702449     4.181100         5.337415  -84.731888
# 2   152.194252  38.776567    -1.737873         8.311220  183.849258
# 3   248.770434  24.396708     2.662585         8.704791 -211.409515
# 4   155.753257  35.437811    -0.873144         8.487546 -147.517960
# 5   217.073745  26.917836     1.566720         8.945233  -34.549957
# 6    81.670731  36.101408    -1.730661         8.230976   65.519203
# 7   219.577239  22.792053     2.126107         4.616644  157.421722
# 8    87.147009  32.620000    -1.471857         3.116946 -119.093552
# 9   202.978559  27.138462     0.946517        -0.390809  -26.108976
# 10   50.308657  29.639098    -2.440001        -1.977513 -126.772224
# 11  168.365547  21.259459     1.298545         7.950309  -51.124294
# 12    4.000000  21.600000    -0.098464        -3.506416   25.866987
# 13    0.000000  19.800000     0.023551        -4.267736 -202.217682
# 14   53.200088  21.687805    -0.315241        -6.259535  203.645920
# 15  201.860105  18.077143     2.748246        -7.570676  -25.014486
# 16  102.681604  31.779310    -1.301930         5.259195  -18.252403
# 17  211.367571  26.676923     0.941261         3.102606   50.353775
# 18  149.557451  33.020690    -0.170770         4.579115  -46.088966
# 19  239.162193  20.449691     3.207283         1.457547   50.228073
# 20  126.563497  31.371429    -0.451470         9.846610  103.700768
# 21  243.804600  12.132561     7.137195        -2.454714   93.253899
# 22   55.688526  47.536057    -6.677410         4.404730 -102.504051
# 23  200.490629  17.605901     4.067062         7.887428   50.288635
# 24   92.894808  28.139664    -1.276232         5.056345  -19.792971
# 25  131.522378  20.547695     1.081617         9.278316   10.587919
# 26  239.409741  25.380106    -0.053718        10.007277  -57.444317
# 27  187.857245  29.429980     0.018851         5.775413   36.829445
# 28  202.329971  20.327268    -0.061448        18.939865   97.389671
# 29   72.243753  28.007125     0.072666         6.786423 -144.719025
# ..         ...        ...          ...              ...         ...
# 46  107.394053  26.449968    -0.814198        -7.359421  222.248199
# 47  185.166411  23.518411     0.689317        -4.762836  129.298584
# 48  104.957116  29.666974    -1.342599        -2.826883   62.067745
# 49  163.792413  24.757710     1.178195        -5.642363 -106.692444
# 50  206.560919   0.770052    -0.303818        -5.120532  110.950333
# 51  194.453542  21.358557     1.358546        -4.543823  -28.670597
# 52  157.112154  32.611553    -1.139543        -3.526838  -72.367973
# 53   89.190067  29.882825     0.045379        -4.710858  104.775696
# 54  133.265456  32.789549    -0.190230        -3.514583  -61.203609
