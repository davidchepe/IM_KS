# %%
import pandas as pd
# %pylab inline
import seaborn as sns
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df_total = pd.read_csv("../Entrenamientos/20180406_LEVS_195_90_R_E_ml.csv")

# %%
df_total.head()
# Out:
#    Unnamed: 0  timeoffset  hr       spd  pwr  cad  dist        lat       lon  \
# 0           0       27865 NaN  5.000000  0.0  NaN   0.0  40.519800 -3.929805
# 1           1       27867 NaN  5.141748  0.0  0.0  15.0  40.519850 -3.929899
# 2           2       27868 NaN  5.200000  0.0  0.0  26.0  40.519883 -3.930019
# 3           3       27870 NaN  5.238999  0.0  0.0  39.0  40.519872 -3.930170
# 4           4       27872 NaN  5.300000  0.0  0.0  52.0  40.519832 -3.930314
#
#           alt     ...        spd_prev    ele_prev  timeoffset_prev  \
# 0  662.799988     ...        0.000000    0.000000                0
# 1  661.417483     ...        0.000000  662.799988            27865
# 2  661.610010     ...        5.892366  661.417483            27867
# 3  659.610010     ...       13.766347  661.610010            27868
# 4  659.000000     ...        8.371067  659.610010            27870
#
#       new_ele  tramo  tramos_100  altura  peso  tpo_bici  tpo_entreno
# 0  661.131985      0           0     195    90         R            E
# 1  660.841092      0           0     195    90         R            E
# 2  660.532461      0           0     195    90         R            E
# 3  660.206093      0           0     195    90         R            E
# 4  659.861987      0           0     195    90         R            E
#
# [5 rows x 27 columns]

# %%
df_total.columns
# Out:
# Index(['Unnamed: 0', 'timeoffset', 'hr', 'spd', 'pwr', 'cad', 'dist', 'lat',
#        'lon', 'alt', 'temp', 'prueba', 'dist_c', 'ele_gain', 'porc', 'spd_c',
#        'bearing', 'spd_prev', 'ele_prev', 'timeoffset_prev', 'new_ele',
#        'tramo', 'tramos_100', 'altura', 'peso', 'tpo_bici', 'tpo_entreno'],
#       dtype='object')

# %%
X = df_total[["pwr","porc"]].values
y = df_total["spd"]
plt.figure(figsize=(10,10))
plt.scatter(X[:,0],X[:,1],c=y,cmap="rainbow")
plt.show()

# %%
plt.hist(X[:,0])
plt.show()

# %%
plt.hist(X[:,1])
plt.show()

# %%
plt.hist(y)
plt.show()

# %%
x1 = pd.Series(df_total["pwr"])
x2 = pd.Series(df_total["porc"])
y = pd.Series(df_total["spd"])
#plt.figure(figsize=(10,10))

g = sns.jointplot(x1, x2,kind='kde', size=7, space=0)
#scatter(X[:,0],X[:,1],c=y,cmap="rainbow")
#plt.show()

# %%
#SEGUIR DESDE AQUI

# %%
from scipy import stats
import numpy as np

def entropy(attribute_data):
    _, val_freqs = np.unique(attribute_data, return_counts=True)
    val_probs = val_freqs / float(len(attribute_data))
    return -val_probs.dot(np.log(val_probs))

# %%
def cut_df(df,feature,percentile):
    return (df[feature].sort_values().iloc[:int(len(df)*percentile/100)].index,
            df[feature].sort_values().iloc[int(len(df)*percentile/100):].index)

def entropy_gain(df,feature,percentile):
    left,right = cut_df(df,feature,percentile)
    return entropy(df["spd"]) \
         - entropy(df["spd"].loc[left])*percentile/100 \
         - entropy(df["spd"].loc[right])*(100-percentile)/100

# %%
entropy(df_total["spd"])
# Out:
# 6.6064614988153849

# %%
#No entiendo nada hasta el siguiente bloque

# %%
feature = "pwr"
gains = [entropy_gain(df_total,feature,i) for i in range(1,100)]
values = [df_total[feature].sort_values().iloc[int(len(df_total)*i/100)] for i in range(1,100)]
plt.plot(values,gains)
print(max(gains))
# Out:
# 0.46335389577

# %%
feature = "porc"
gains = [entropy_gain(df_total,feature,i) for i in range(1,100)]
values = [df_total[feature].sort_values().iloc[int(len(df_total)*i/100)] for i in range(1,100)]
plt.plot(values,gains)
print(max(gains))
# Out:
# 0.468949256882

# %%
# So we cut by grade in 0.5

# %%
df_left = df_total[df_total["pwr"]<=150]

# %%
feature = "pwr"
gains = [entropy_gain(df_left,feature,i) for i in range(1,100)]
values = [df_left[feature].sort_values().iloc[int(len(df_left)*i/100)] for i in range(1,100)]
plt.plot(values,gains)
print(max(gains))
# Out:
# 0.485693837514

# %%
feature = "porc"
gains = [entropy_gain(df_left,feature,i) for i in range(1,100)]
values = [df_left[feature].sort_values().iloc[int(len(df_left)*i/100)] for i in range(1,100)]
plt.plot(values,gains)
print(max(gains))
# Out:
# 0.471446692074

# %%
# So we would do the cut in 0.78 for bumpiness

# %% [markdown]
# # sklearn Implementation

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier(criterion="entropy",max_depth=3)

# %%
df_total['spd'].describe()
# Out:
# count    7586.000000
# mean        8.369993
# std         4.609740
# min         0.000000
# 25%         4.300000
# 50%         7.700000
# 75%        11.445358
# max        22.700001
# Name: spd, dtype: float64

# %%
clf.fit??

# %%
#Tengo que convertir spd a int porque al arbol no le gusta en continuo

# %%
clf = clf.fit(df_total[["pwr","porc"]], df_total["spd"].astype('int'))

# %%
#Problemas con la imagen

# %%
from IPython.display import Image  
import pydotplus
dot_data = tree.export_graphviz(clf, out_file=None, 
                         feature_names=["pwr", "porc"], 
                         #class_names=["Slow","Fast"], 
                         filled=True, rounded=True,  
                         special_characters=True)  
graph = pydotplus.graph_from_dot_data(dot_data)
Image(graph.create_png())
# Out:
# ---------------------------------------------------------------------------
# InvocationException                       Traceback (most recent call last)
# <ipython-input-56-e949184ae23a> in <module>()
#       7                          special_characters=True)
#       8 graph = pydotplus.graph_from_dot_data(dot_data)
# ----> 9 Image(graph.create_png())
#
# C:\Users\David\Anaconda3\lib\site-packages\pydotplus\graphviz.py in <lambda>(f, prog)
#    1795             self.__setattr__(
#    1796                 'create_' + frmt,
# -> 1797                 lambda f=frmt, prog=self.prog: self.create(format=f, prog=prog)
#    1798             )
#    1799             f = self.__dict__['create_' + frmt]
#
# C:\Users\David\Anaconda3\lib\site-packages\pydotplus\graphviz.py in create(self, prog, format)
#    1958             if self.progs is None:
#    1959                 raise InvocationException(
# -> 1960                     'GraphViz\'s executables not found')
#    1961
#    1962         if prog not in self.progs:
#
# InvocationException: GraphViz's executables not found

# %%
graph = pydotplus.graph_from_dot_data(dot_data)

# %%
Image(graph.create_png())

# %%
X = df_total[["pwr","porc"]].values
y = df_total["spd"].astype('int')

# %%
def represent_clf(clf,X,y,h = .1,show=False):
    x_min, x_max = X[:, 0].min() - 0.1, X[:, 0].max() + .1
    y_min, y_max = X[:, 1].min() - .1, X[:, 1].max() + .1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    plt.figure(figsize=(10,10))
    plt.scatter(xx, yy,c=Z)
    if show:
        plt.scatter(X[:,0],X[:,1],c=y,cmap="rainbow")
    return plt.show()

# %%
represent_clf(clf,X,y,0.1,True)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
y_train = y_train.astype('int')
y_test = y_test.astype('int')

# %%
from sklearn.model_selection import cross_val_score
np.mean(cross_val_score(clf,X,y,cv=10,scoring="accuracy"))
# Out:
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:581: Warning: The least populated class in y has only 6 members, which is too few. The minimum number of groups for any class cannot be less than n_splits=10.
#   % (min_groups, self.n_splits)), Warning)
# 0.21157952838600336

# %%
#Vaya Mierda... de accuracy

# %%
from sklearn.model_selection import GridSearchCV
clf_good = GridSearchCV(tree.DecisionTreeClassifier(),
                        param_grid={"max_depth":range(1,100)},
                        scoring="precision",
                        cv=10)

# %%
#Falla y lo dejo aqui...

# %%
clf_good.fit(X_train,y_train)
print(clf_good.best_params_)
# Out:
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:581: Warning: The least populated class in y has only 5 members, which is too few. The minimum number of groups for any class cannot be less than n_splits=10.
#   % (min_groups, self.n_splits)), Warning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-fb16bb648306> in <module>()
# ----> 1 clf_good.fit(X_train,y_train)
#       2 print(clf_good.best_params_)
#
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups)
#     943             train/test set.
#     944         """
# --> 945         return self._fit(X, y, groups, ParameterGrid(self.param_grid))
#     946
#     947
#
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py in _fit(self, X, y, groups, parameter_iterable)
#     562                                   return_times=True, return_parameters=True,
#     563                                   error_score=self.error_score)
# --> 564           for parameters in parameter_iterable
#     565           for train, test in cv_iter)
#     566
#
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\externals\joblib\parallel.py in __call__(self, iterable)
#     756             # was dispatched. In particular this covers the edge
#     757             # case of Parallel used with an exhausted iterator.
# --> 758             while self.dispatch_one_batch(iterator):
#     759                 self._iterating = True
#     760             else:
#
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\externals\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     606                 return False
#     607             else:
# --> 608                 self._dispatch(tasks)
#     609                 return True
#     610
#
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\externals\joblib\parallel.py in _dispatch(self, batch)
#     569         dispatch_timestamp = time.time()
#     570         cb = BatchCompletionCallBack(dispatch_timestamp, len(batch), self)
# --> 571         job = self._backend.apply_async(batch, callback=cb)
#     572         self._jobs.append(job)
#     573
#
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\externals\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     107     def apply_async(self, func, callback=None):
#     108         """Schedule a func to be run"""
# --> 109         result = ImmediateResult(func)
#     110         if callback:
#     111             callback(result)
#
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\externals\joblib\_parallel_backends.py in __init__(self, batch)
#     324         # Don't delay the application, to avoid keeping the input
#     325         # arguments in memory
# --> 326         self.results = batch()
#     327
#     328     def get(self):
#
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\externals\joblib\parallel.py in __call__(self)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\externals\joblib\parallel.py in <listcomp>(.0)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, error_score)
#     258     else:
#     259         fit_time = time.time() - start_time
# --> 260         test_score = _score(estimator, X_test, y_test, scorer)
#     261         score_time = time.time() - start_time - fit_time
#     262         if return_train_score:
#
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in _score(estimator, X_test, y_test, scorer)
#     286         score = scorer(estimator, X_test)
#     287     else:
# --> 288         score = scorer(estimator, X_test, y_test)
#     289     if hasattr(score, 'item'):
#     290         try:
#
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\metrics\scorer.py in __call__(self, estimator, X, y_true, sample_weight)
#      96         else:
#      97             return self._sign * self._score_func(y_true, y_pred,
# ---> 98                                                  **self._kwargs)
#      99
#     100
#
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in precision_score(y_true, y_pred, labels, pos_label, average, sample_weight)
#    1237                                                  average=average,
#    1238                                                  warn_for=('precision',),
# -> 1239                                                  sample_weight=sample_weight)
#    1240     return p
#    1241
#
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight)
#    1016         else:
#    1017             raise ValueError("Target is %s but average='binary'. Please "
# -> 1018                              "choose another average setting." % y_type)
#    1019     elif pos_label not in (None, 1):
#    1020         warnings.warn("Note that pos_label (set to %r) is ignored when "
#
# ValueError: Target is multiclass but average='binary'. Please choose another average setting.

# %%
nclf=tree.DecisionTreeClassifier(**clf_good.best_params_)
nclf
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=3,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
np.mean(cross_val_score(nclf,X,y,cv=10,scoring="accuracy"))
# Out:
# 0.90898409840984107

# %%
nclf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=3,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
represent_clf(clf,X,y,0.01,True)

# %% [markdown]
# ## Notion of Predict Probability

# %%
nclf.predict_proba(X_test)[:10]
# Out:
# array([[ 1.        ,  0.        ],
#        [ 1.        ,  0.        ],
#        [ 1.        ,  0.        ],
#        [ 0.0070922 ,  0.9929078 ],
#        [ 1.        ,  0.        ],
#        [ 0.89090909,  0.10909091],
#        [ 0.66666667,  0.33333333],
#        [ 0.0070922 ,  0.9929078 ],
#        [ 0.0070922 ,  0.9929078 ],
#        [ 0.66666667,  0.33333333]])

# %% [markdown]
# ## ROC Curve

# %%
# http://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_curve.html
# https://datamize.wordpress.com/2015/01/24/how-to-plot-a-roc-curve-in-scikit-learn/
# http://gim.unmc.edu/dxtests/roc3.htm

# %%
from sklearn.metrics import roc_curve, auc

# %%
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, nclf.predict_proba(X_test)[:,1])
roc_auc = auc(false_positive_rate, true_positive_rate)

# %%
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate, true_positive_rate, 'b',
label='AUC = %0.2f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.1,1.2])
plt.ylim([-0.1,1.2])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
from sklearn.linear_model import LogisticRegression

# %%
bclf = LogisticRegression()
bclf.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, bclf.predict_proba(X_test)[:,1])
roc_auc = auc(false_positive_rate, true_positive_rate)

# %%
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate, true_positive_rate, 'b',
label='AUC = %0.2f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.1,1.2])
plt.ylim([-0.1,1.2])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# ## Precision Recall Curve

# %%
# http://scikit-learn.org/stable/modules/generated/sklearn.metrics.precision_recall_curve.html

# %%
# https://www.coursera.org/learn/ml-classification/lecture/rENu8/precision-recall-curve

# %%
from sklearn.metrics import precision_recall_curve

y_score = nclf.predict_proba(X_test)[:,1]
precision, recall, _ = precision_recall_curve(y_test, y_score)

# %%
from sklearn.metrics import average_precision_score
average_precision = average_precision_score(y_test, y_score)

print('Average precision-recall score: {0:0.2f}'.format(
      average_precision))
# Out:
# Average precision-recall score: 0.96

# %%
plt.step(recall, precision, color='b', alpha=0.2,
         where='post')
plt.fill_between(recall, precision, step='post', alpha=0.2,
                 color='b')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title('2-class Precision-Recall curve: AP={0:0.2f}'.format(
          average_precision))
# Out:
# Text(0.5,1,'2-class Precision-Recall curve: AP=0.96')

# %%
from sklearn.metrics import precision_recall_curve

y_score = bclf.predict_proba(X_test)[:,1]
precision, recall, _ = precision_recall_curve(y_test, y_score)
from sklearn.metrics import average_precision_score
average_precision = average_precision_score(y_test, y_score)

print('Average precision-recall score: {0:0.2f}'.format(
      average_precision))
plt.step(recall, precision, color='b', alpha=0.2,
         where='post')
plt.fill_between(recall, precision, step='post', alpha=0.2,
                 color='b')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title('2-class Precision-Recall curve: AP={0:0.2f}'.format(
          average_precision))
# Out:
# Average precision-recall score: 0.99
# Text(0.5,1,'2-class Precision-Recall curve: AP=0.99')
